# %% [markdown]
# # Investigation 03: Carrier Aggregation Study of a 5G NR Radio Access Network using ns-3
#
# ### Authors : Daniel (UFRN), Vicente Sousa (UFRN)
#
# **Targets:**
# - HOWTO material to download, configure and compile the code;
# - HOWTO material to create, run and plot simulations results (including Python scripts);
# - Preliminaly analyses of simulation results.

# %% [markdown]
# ### Benchmarking campaign 1:
#
# UePosY = 0, which means random position allocation;
# numerology = 1;

# %%
path = "/home/master/ns-3/ns-allinone-3.31/ns-3.31/ScriptsPlot"
pathPlot = "/home/master/ns-3/ns-allinone-3.31/ns-3.31" + "/"

# %%
# %cd $path
# %run PlotNrCaScript_BenchmarkingRcc -f "NrCa_Scenario3gpp_UePosY0_Benchmarking.yaml" -p $pathPlot"results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2"
# Out:
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/ScriptsPlot
# Simulação escolhida:
# ['bandwidthBwp2']
#
#
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB0/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB1/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB2/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB3/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB4/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB5/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB6/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB7/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB8/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB9/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB10/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB11/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB12/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB13/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB14/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB15/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB16/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB17/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB18/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB19/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB20/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB21/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB22/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB23/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB24/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB25/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB26/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB27/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB28/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB29/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB30/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB31/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB32/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB33/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB34/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB35/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB36/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB37/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB38/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB39/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB40/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB41/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB42/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB43/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB44/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB45/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB46/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB47/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB48/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB49/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB50/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB51/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB52/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB53/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB54/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB55/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB56/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB57/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB58/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB59/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB60/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB61/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB62/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB63/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB64/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB65/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB66/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB67/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB68/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB69/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB70/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB71/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB72/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB73/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB74/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB75/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB76/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB77/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB78/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB79/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB80/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB81/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB82/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB83/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB84/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB85/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB86/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB87/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB88/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB89/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB90/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB91/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB92/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB93/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB94/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB95/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB96/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB97/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB98/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB99/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
#
#
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB0/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB1/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB2/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB3/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB4/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB5/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB6/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB7/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB8/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB9/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB10/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB11/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB12/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB13/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB14/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB15/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB16/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB17/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB18/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB19/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB20/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB21/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB22/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB23/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB24/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB25/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB26/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB27/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB28/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB29/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB30/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB31/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB32/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB33/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB34/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB35/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB36/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB37/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB38/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB39/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB40/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB41/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB42/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB43/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB44/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB45/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB46/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB47/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB48/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB49/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB50/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB51/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB52/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB53/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB54/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB55/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB56/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB57/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB58/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB59/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB60/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB61/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB62/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB63/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB64/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB65/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB66/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB67/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB68/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB69/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB70/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB71/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB72/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB73/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB74/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB75/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB76/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB77/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# ...
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB42/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB43/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB44/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB45/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB46/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB47/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB48/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB49/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB50/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB51/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB52/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB53/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB54/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB55/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB56/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB57/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB58/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB59/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB60/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB61/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB62/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB63/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB64/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB65/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB66/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB67/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB68/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB69/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB70/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB71/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB72/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB73/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB74/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB75/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB76/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB77/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB78/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB79/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB80/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB81/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB82/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB83/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB84/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB85/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB86/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB87/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB88/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB89/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB90/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB91/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB92/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB93/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB94/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB95/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB96/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB97/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB98/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY0_Benchmarking_bandwidthBwp2/JOB99/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_0_UseCa_1_UseBlockage_0.txt
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Benchmarking Campaign 2:
#
# UePosY = 1;
# numerology = 1;

# %%
# %cd $path
# %run PlotNrCaScript_BenchmarkingRcc -f "NrCa_Scenario3gpp_UePosY1_Benchmarking.yaml" -p $pathPlot"results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2"
# Out:
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/ScriptsPlot
# Simulação escolhida:
# ['bandwidthBwp2']
#
#
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB0/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB1/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB2/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB3/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB4/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB5/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB6/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB7/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB8/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB9/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB10/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB11/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB12/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB13/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB14/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB15/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB16/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB17/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB18/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB19/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB20/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB21/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB22/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB23/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB24/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB25/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB26/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB27/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB28/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB29/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB30/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB31/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB32/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB33/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB34/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB35/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB36/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB37/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB38/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB39/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB40/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB41/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB42/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB43/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB44/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB45/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB46/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB47/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB48/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB49/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB50/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB51/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB52/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB53/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB54/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB55/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB56/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB57/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB58/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB59/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB60/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB61/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB62/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB63/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB64/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB65/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB66/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB67/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB68/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB69/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB70/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB71/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB72/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB73/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB74/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB75/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB76/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB77/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB78/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB79/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB80/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB81/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB82/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB83/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB84/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB85/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB86/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB87/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB88/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB89/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB90/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB91/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB92/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB93/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB94/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB95/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB96/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB97/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB98/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB99/DL_Results_Results_Freq1_39.50_Band1_664_Freq2_40.16_Band2_336_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
#
#
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB0/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB1/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB2/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB3/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB4/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB5/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB6/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB7/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB8/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB9/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB10/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB11/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB12/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB13/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB14/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB15/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB16/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB17/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB18/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB19/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB20/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB21/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB22/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB23/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB24/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB25/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB26/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB27/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB28/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB29/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB30/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB31/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB32/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB33/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB34/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB35/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB36/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB37/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB38/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB39/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB40/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB41/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB42/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB43/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB44/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB45/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB46/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB47/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB48/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB49/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB50/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB51/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB52/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB53/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB54/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB55/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB56/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB57/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB58/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB59/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB60/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB61/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB62/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB63/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB64/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB65/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB66/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB67/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB68/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB69/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB70/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB71/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB72/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB73/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB74/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB75/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB76/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB77/DL_Results_Results_Freq1_39.50_Band1_796_Freq2_40.30_Band2_204_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# ...
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB42/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB43/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB44/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB45/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB46/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB47/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB48/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB49/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB50/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB51/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB52/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB53/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB54/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB55/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB56/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB57/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB58/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB59/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB60/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB61/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB62/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB63/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB64/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB65/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB66/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB67/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB68/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB69/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB70/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB71/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB72/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB73/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB74/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB75/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB76/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB77/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB78/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB79/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB80/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB81/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB82/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB83/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB84/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB85/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB86/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB87/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB88/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB89/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB90/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB91/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB92/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB93/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB94/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB95/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB96/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB97/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB98/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_UePosY1_Benchmarking_bandwidthBwp2/JOB99/DL_Results_Results_Freq1_39.50_Band1_892_Freq2_40.39_Band2_108_BitRate_4000_UePosY_1_UseCa_1_UseBlockage_0.txt
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Campaign 1
#
#
# **Scenario**
#  - UEs = 1;
#  - gNBs = 1;
#  - gNB and UE have constant position;
#
# **Bandwidth Part 1**
#  - numerology = 1;
#  - frequency = ;
#  - bandwidth = ;
#
# **Bandwidth Part 2**
#  - numerology = 1;
#  - frequency = ;
#  - bandwidth = ;

# %%
# %cd $path
#%run PlotNrCaScript_Bitrate
# %run PlotNrCaScript_Bitrate -f "NrCa_Scenario3gpp_campaign1.yaml" -p $pathPlot"results_cluster_NrCa_Scenario3gpp_campaign1_BitRate"
# Out:
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/ScriptsPlot
# Simulação escolhida:
# ['BitRate']
# 3 1 2

# %%
# %cd $path
#%run PlotNrCaScript_Bitrate
# %run PlotNrCaScript_Bitrate -f "NrCa_Scenario3gpp_campaign1.yaml" -p $pathPlot"results_cluster_NrCa_Scenario3gpp_campaign1_BitRate"
# Out:
# /media/daniel/SharedDisk/Clouds/Insync/SharedWithMe/UFRN/GITHUB/ns3-nr/Campaigns/ScriptsPlot
# Simulação escolhida:
# ['BitRate']
# 3 1 2

# %% [markdown]
# ### Campaign 2
#
#
# **Scenario**
#  - UEs = 1;
#  - gNBs = 1;
#  - gNB and UE have constant position;
#
# **Bandwidth Part 1**
#  - numerology = 1;
#  - frequency = ;
#  - bandwidth = ;
#
# **Bandwidth Part 2**
#  - numerology = 1;
#  - frequency = ;
#  - bandwidth = ;

# %%
# %cd $path
#%run PlotNrCaScript_Bitrate
# %run PlotNrCaScript_Bitrate -f "NrCa_Scenario3gpp_campaign2.yaml" -p $pathPlot"results_cluster_NrCa_Scenario3gpp_campaign2_BitRate"
# Out:
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/ScriptsPlot
# Simulação escolhida:
# ['BitRate']
# 3 1 2

# %% [markdown]
# ### Campaign 3
#
# UePosY = 1;
# numerology = 1;

# %%
# %cd $path
# %run PlotNrCaScript_Rcc -f "NrCa_Scenario3gpp_campaign3.yaml" -p $pathPlot"results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2"
# Out:
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/ScriptsPlot
# Simulação escolhida:
# ['bandwidthBwp2']
# 2 1 2
#
#
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB0/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB1/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB2/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB3/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB4/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB5/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB6/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB7/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB8/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB9/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB10/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB11/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB12/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB13/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB14/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB15/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB16/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB17/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB18/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB19/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB20/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB21/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB22/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB23/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB24/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB25/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB26/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB27/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB28/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB29/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB30/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB31/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB32/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB33/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB34/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB35/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB36/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB37/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB38/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB39/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB40/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB41/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB42/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB43/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB44/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB45/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB46/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB47/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB48/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB49/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB50/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB51/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB52/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB53/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB54/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB55/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB56/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB57/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB58/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB59/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB60/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB61/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB62/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB63/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB64/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB65/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB66/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB67/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB68/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB69/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB70/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB71/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB72/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB73/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB74/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB75/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB76/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB77/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB78/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB79/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB80/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB81/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB82/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB83/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB84/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB85/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB86/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB87/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB88/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB89/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB90/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB91/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB92/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB93/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB94/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB95/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB96/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB97/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB98/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB99/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
#
#
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB0/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB1/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB2/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB3/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB4/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB5/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB6/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB7/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB8/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB9/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB10/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB11/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB12/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB13/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB14/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB15/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB16/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB17/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB18/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB19/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB20/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB21/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB22/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB23/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB24/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB25/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB26/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB27/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB28/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB29/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB30/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB31/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB32/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB33/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB34/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB35/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB36/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB37/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB38/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB39/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB40/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB41/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB42/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB43/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB44/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB45/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB46/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB47/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB48/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB49/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB50/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB51/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB52/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB53/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB54/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB55/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB56/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB57/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB58/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB59/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB60/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB61/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB62/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB63/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB64/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB65/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB66/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB67/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB68/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB69/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB70/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB71/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB72/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB73/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB74/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB75/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB76/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB77/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB78/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB79/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB80/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB81/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB82/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB83/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB84/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB85/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# ...
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB39/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB40/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB41/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB42/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB43/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB44/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB45/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB46/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB47/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB48/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB49/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB50/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB51/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB52/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB53/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB54/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB55/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB56/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB57/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB58/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB59/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB60/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB61/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB62/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB63/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB64/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB65/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB66/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB67/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB68/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB69/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB70/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB71/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB72/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB73/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB74/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB75/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB76/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB77/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB78/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB79/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB80/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB81/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB82/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB83/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB84/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB85/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB86/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB87/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB88/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB89/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB90/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB91/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB92/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB93/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB94/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB95/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB96/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB97/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB98/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign3_bandwidthBwp2/JOB99/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_1_UseCa_1_UseBlockage_0.txt
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Campaign 4
#
# UePosY = 0, which means random position allocation;
# numerology = 1;

# %%
# %cd $path
# %run PlotNrCaScript_Rcc -f "NrCa_Scenario3gpp_campaign4.yaml" -p $pathPlot"results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2"
# Out:
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/ScriptsPlot
# Simulação escolhida:
# ['bandwidthBwp2']
# 2 1 2
#
#
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB0/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB1/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB2/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB3/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB4/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB5/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB6/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB7/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB8/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB9/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB10/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB11/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB12/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB13/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB14/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB15/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB16/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB17/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB18/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB19/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB20/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB21/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB22/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB23/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB24/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB25/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB26/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB27/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB28/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB29/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB30/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB31/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB32/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB33/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB34/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB35/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB36/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB37/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB38/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB39/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB40/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB41/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB42/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB43/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB44/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB45/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB46/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB47/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB48/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB49/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB50/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB51/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB52/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB53/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB54/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB55/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB56/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB57/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB58/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB59/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB60/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB61/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB62/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB63/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB64/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB65/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB66/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB67/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB68/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB69/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB70/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB71/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB72/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB73/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB74/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB75/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB76/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB77/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB78/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB79/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB80/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB81/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB82/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB83/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB84/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB85/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB86/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB87/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB88/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB89/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB90/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB91/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB92/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB93/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB94/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB95/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB96/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB97/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB98/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB99/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
#
#
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB0/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB1/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB2/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB3/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB4/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB5/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB6/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB7/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB8/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB9/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB10/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB11/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB12/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB13/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB14/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB15/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB16/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB17/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB18/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB19/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB20/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB21/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB22/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB23/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB24/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB25/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB26/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB27/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB28/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB29/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB30/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB31/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB32/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB33/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB34/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB35/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB36/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB37/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB38/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB39/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB40/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB41/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB42/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB43/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB44/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB45/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB46/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB47/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB48/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB49/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB50/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB51/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB52/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB53/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB54/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB55/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB56/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB57/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB58/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB59/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB60/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB61/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB62/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB63/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB64/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB65/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB66/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB67/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB68/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB69/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB70/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB71/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB72/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB73/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB74/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB75/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB76/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB77/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB78/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB79/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB80/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB81/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB82/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB83/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB84/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB85/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# ...
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB39/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB40/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB41/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB42/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB43/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB44/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB45/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB46/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB47/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB48/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB49/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB50/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB51/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB52/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB53/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB54/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB55/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB56/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB57/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB58/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB59/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB60/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB61/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB62/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB63/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB64/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB65/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB66/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB67/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB68/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB69/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB70/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB71/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB72/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB73/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB74/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB75/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB76/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB77/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB78/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB79/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB80/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB81/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB82/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB83/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB84/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB85/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB86/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB87/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB88/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB89/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB90/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB91/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB92/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB93/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB94/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB95/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB96/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB97/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB98/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB99/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# %cd $path
# %run PlotNrCaScript_Rcc -f "NrCa_Scenario3gpp_campaign4.yaml" -p $pathPlot"results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2"
# Out:
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/ScriptsPlot
# Simulação escolhida:
# ['bandwidthBwp2']
# 2 1 2
#
#
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB0/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB1/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB2/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB3/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB4/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB5/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB6/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB7/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB8/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB9/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB10/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB11/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB12/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB13/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB14/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB15/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB16/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB17/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB18/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB19/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB20/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB21/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB22/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB23/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB24/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB25/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB26/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB27/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB28/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB29/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB30/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB31/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB32/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB33/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB34/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB35/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB36/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB37/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB38/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB39/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB40/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB41/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB42/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB43/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB44/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB45/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB46/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB47/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB48/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB49/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB50/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB51/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB52/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB53/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB54/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB55/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB56/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB57/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB58/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB59/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB60/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB61/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB62/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB63/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB64/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB65/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB66/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB67/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB68/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB69/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB70/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB71/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB72/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB73/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB74/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB75/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB76/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB77/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB78/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB79/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB80/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB81/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB82/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB83/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB84/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB85/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB86/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB87/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB88/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB89/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB90/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB91/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB92/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB93/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB94/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB95/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB96/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB97/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB98/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB99/DL_Results_Results_Freq1_24.00_Band1_532_Freq2_24.53_Band2_268_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
#
#
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB0/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB1/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB2/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB3/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB4/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB5/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB6/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB7/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB8/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB9/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB10/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB11/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB12/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB13/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB14/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB15/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB16/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB17/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB18/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB19/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB20/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB21/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB22/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB23/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB24/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB25/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB26/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB27/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB28/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB29/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB30/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB31/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB32/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB33/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB34/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB35/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB36/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB37/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB38/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB39/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB40/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB41/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB42/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB43/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB44/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB45/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB46/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB47/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB48/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB49/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB50/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB51/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB52/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB53/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB54/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB55/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB56/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB57/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB58/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB59/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB60/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB61/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB62/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB63/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB64/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB65/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB66/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB67/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB68/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB69/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB70/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB71/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB72/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB73/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB74/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB75/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB76/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB77/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB78/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB79/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB80/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB81/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB82/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB83/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB84/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB85/DL_Results_Results_Freq1_24.00_Band1_640_Freq2_24.64_Band2_160_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# ...
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB39/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB40/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB41/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB42/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB43/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB44/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB45/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB46/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB47/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB48/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB49/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB50/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB51/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB52/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB53/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB54/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB55/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB56/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB57/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB58/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB59/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB60/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB61/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB62/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB63/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB64/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB65/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB66/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB67/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB68/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB69/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB70/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB71/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB72/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB73/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB74/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB75/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB76/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB77/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB78/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB79/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB80/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB81/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB82/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB83/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB84/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB85/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB86/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB87/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB88/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB89/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB90/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB91/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB92/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB93/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB94/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB95/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB96/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB97/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB98/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_campaign4_bandwidthBwp2/JOB99/DL_Results_Results_Freq1_24.00_Band1_712_Freq2_24.71_Band2_80_BitRate_3200_UePosY_0_UseCa_1_UseBlockage_0.txt
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Campaign 5
#
#
# **Scenario**
#  - UEs = 1;
#  - gNBs = 1;
#  - gNB and UE have constant position;
#
# **Bandwidth Part 1**
#  - numerology = 1;
#  - frequency = ;
#  - bandwidth = ;
#
# **Bandwidth Part 2**
#  - numerology = 1;
#  - frequency = ;
#  - bandwidth = ;

# %%
# %cd $path

#%run PlotNrCaScript_Bitrate
# %run PlotNrCaScript_UePosY -f "NrCa_Scenario3gpp_campaign5.yaml" -p $pathPlot"results_cluster_NrCa_Scenario3gpp_campaign5_UePosY"
# Out:
# /media/daniel/SharedDisk/Insync/danieluna6@gmail.com/UFRN/GITHUB/ns3-nr/Campaigns/ScriptsPlot
# Simulação escolhida:
# ['UePosY']
# 3 1 2

# %% [markdown]
# ## SimPerScript Campaigns

# %% [markdown]
# ### Campaign 1

# %%
# %cd $path
#%run PlotNrCaScript_Bitrate
# %run PlotNrCaScript_Bitrate -f "NrCa_Scenario3gpp_SimPerScript_campaign1.yaml" -p $pathPlot"results_cluster_NrCa_Scenario3gpp_SimPerScript_campaign1_BitRate"
# Out:
# /media/daniel/SharedDisk/Clouds/Insync/SharedWithMe/UFRN/GITHUB/ns3-nr/Campaigns/ScriptsPlot
# Simulação escolhida:
# ['BitRate']
# 2 1 2

# %% [markdown]
# ### Campaign 2

# %%
# %cd $path
#%run PlotNrCaScript_Bitrate
# %run PlotNrCaScript_Bitrate -f "NrCa_Scenario3gpp_SimPerScript_campaign2.yaml" -p $pathPlot"results_cluster_NrCa_Scenario3gpp_SimPerScript_campaign2_BitRate"
# Out:
# /media/daniel/SharedDisk/Clouds/Insync/SharedWithMe/UFRN/GITHUB/ns3-nr/Campaigns/ScriptsPlot
# Simulação escolhida:
# ['BitRate']
# 3 1 3

# %% [markdown]
# ### Campaign 5

# %%
# %cd $path

#%run PlotNrCaScript_Bitrate
# %run PlotNrCaScript_UePosY -f "NrCa_Scenario3gpp_SimPerScript_campaign5.yaml" -p $pathPlot"results_cluster_NrCa_Scenario3gpp_SimPerScript_campaign5_UePosY"
# Out:
# /media/daniel/SharedDisk/Clouds/Insync/SharedWithMe/UFRN/GITHUB/ns3-nr/Campaigns/ScriptsPlot
# Simulação escolhida:
# ['UePosY']
# 3 1 2

# %% [markdown]
# O uso do blockage aparentemente tem influência no gráfico a partir da distância de 50m, chegando a perder em torno de 50% da taxa no pior caso, que é sem CA e com blockage quando comparado o melhor caso (com CA e sem blockage). O gráfico torna difícil de visualizar, mas ajustando a escala é possível perceber esse comportamento.

# %% [markdown]
# ## Campaign 1 - UAN

# %%
# %cd $path

#%run PlotUan_SimPerScript_campaign1
# %run PlotUan_SimPerScript_campaign1 -f "Uan_SimPerScript_campaign1.yaml" -p $pathPlot"results_cluster_Uan_SimPerScript_campaign1_MaxRange"
# Out:
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/ScriptsPlot
# Simulação escolhida:
# ['MaxRange']
# 1 0 0
#
#
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB0/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB1/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB2/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB3/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB4/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB5/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB6/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB7/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB8/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB9/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB10/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB11/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB12/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB13/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB14/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB15/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB16/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB17/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB18/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB19/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB20/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB21/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB22/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB23/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB24/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB25/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB26/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB27/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB28/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB29/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB30/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB31/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB32/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB33/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB34/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB35/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB36/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB37/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB38/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB39/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB40/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB41/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB42/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB43/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB44/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB45/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB46/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB47/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB48/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB49/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB50/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB51/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB52/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB53/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB54/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB55/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB56/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB57/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB58/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB59/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB60/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB61/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB62/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB63/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB64/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB65/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB66/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB67/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB68/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB69/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB70/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB71/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB72/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB73/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB74/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB75/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB76/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB77/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB78/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB79/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB80/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB81/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB82/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB83/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB84/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB85/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB86/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB87/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB88/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB89/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB90/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB91/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB92/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB93/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB94/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB95/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB96/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB97/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB98/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB99/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_1.txt
#
#
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB0/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB1/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB2/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB3/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB4/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB5/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB6/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB7/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB8/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB9/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB10/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB11/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB12/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB13/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB14/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB15/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB16/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB17/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB18/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB19/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB20/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB21/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB22/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB23/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB24/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB25/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB26/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB27/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB28/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB29/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB30/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB31/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB32/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB33/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB34/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB35/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB36/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB37/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB38/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB39/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB40/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB41/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB42/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB43/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB44/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB45/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB46/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB47/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB48/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB49/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB50/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB51/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB52/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB53/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB54/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB55/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB56/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB57/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB58/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB59/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB60/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB61/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB62/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB63/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB64/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB65/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB66/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB67/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB68/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB69/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB70/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB71/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB72/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB73/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB74/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB75/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB76/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB77/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB78/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB79/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB80/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB81/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB82/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB83/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB84/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB85/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB86/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB87/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB88/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB89/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB90/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB91/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB92/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB93/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB94/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB95/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB96/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB97/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB98/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB99/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_2.txt
#
#
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB0/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB1/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB2/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB3/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB4/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB5/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB6/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB7/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB8/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB9/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB10/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB11/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB12/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB13/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB14/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB15/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB16/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB17/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB18/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB19/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB20/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB21/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB22/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB23/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB24/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB25/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB26/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB27/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB28/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB29/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB30/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB31/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB32/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB33/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB34/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB35/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB36/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB37/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB38/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB39/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB40/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB41/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB42/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB43/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB44/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB45/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB46/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB47/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB48/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB49/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB50/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB51/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB52/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB53/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB54/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB55/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB56/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB57/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB58/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB59/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB60/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB61/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB62/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB63/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB64/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB65/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB66/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB67/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB68/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB69/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB70/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB71/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB72/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB73/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB74/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB75/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB76/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB77/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB78/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB79/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_10_AuvModel_3.txt
# ...
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB26/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB27/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB28/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB29/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB30/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB31/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB32/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB33/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB34/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB35/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB36/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB37/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB38/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB39/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB40/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB41/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB42/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB43/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB44/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB45/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB46/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB47/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB48/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB49/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB50/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB51/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB52/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB53/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB54/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB55/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB56/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB57/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB58/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB59/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB60/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB61/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB62/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB63/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB64/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB65/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB66/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB67/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB68/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB69/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB70/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB71/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB72/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB73/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB74/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB75/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB76/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB77/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB78/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB79/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB80/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB81/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB82/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB83/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB84/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB85/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB86/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB87/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB88/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB89/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB90/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB91/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB92/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB93/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB94/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB95/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB96/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB97/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB98/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/results_cluster_Uan_SimPerScript_campaign1_MaxRange/JOB99/UL_Results_Sim_PropModel_UanPropModelIdeal_MaxRange_5000_AuvModel_3.txt
# [  10 1000 2000 3000 4000 5000]
# [0.25419756 0.25368933 0.24953945 0.26658396 0.26378365 0.25595901
#  0.26347635 0.25998648 0.26201938 0.26675656 0.26534754 0.25949964
#  0.27412577 0.26604369 0.26988816 0.         0.         0.        ]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/ns-3/ns-allinone-3.31/ns-3.31/ScriptsPlot/PlotUan_SimPerScript_campaign1.py in <module>
#     504             or str(simC) == 'BitRate'or str(simC) == 'UseCa' or str(simC) == 'UePosY'
#     505             or str(simC) == 'MaxRange'):
# --> 506             simu.plotCampaign(simC,iMet);
#     507         else:
#     508             print('Invalid simulation campaign: verify the campaign parameter!')
#
# ~/ns-3/ns-allinone-3.31/ns-3.31/ScriptsPlot/PlotUan_SimPerScript_campaign1.py in plotCampaign(self, curCampaign, metric)
#     154                     print(resxData)
#     155                     print(mm_plr)
# --> 156                     plt.plot(resxData,mm_plr, label=label, marker=marker,color=color,markevery=markers_on)
#     157                     #plt.errorbar(resxData,mm_tput, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
#     158                     color=next(colors)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (6,) and (18,)

# %% [markdown]
# ## Plot Scripts

# %% [markdown]
# ## For benchmarking campaigns

# %%
# %cd "/home/daniel/ns-3/NR/ns-3-dev-nr/ScriptsPlot"
# Out:
# /home/daniel/ns-3/NR/ns-3-dev-nr/ScriptsPlot

# %%
# %%file PlotNrCaScript_BenchmarkingRcc.py
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pylab as plt
from itertools import cycle
import scipy.stats as st
import os
import argparse
import yaml
import matplotlib
from random import randint   
import itertools  


class openSimulation:
    def __init__(self, configurations_file):
        self.email_to = 'fulano@gmail.com'            
        with open(configurations_file, 'r') as f:
            self.doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
            #self.doc = doc
        self.campaign_name = os.path.splitext(configurations_file)[0]
        
        # Read commom parameters
        self.showPlot = True;
        self.plotCI = True;                
        self.campaignX = self.doc['scenario']['campaignX']
        self.campaignLines = self.doc['scenario']['campaignLines']
        self.simLocation = str(doc['scenario']['simLocation'])
        self.SimTime = self.doc['scenario']['SimTime']
        #self.numerologyBwp1 = self.doc['scenario']['numerologyBwp1']
        #self.numerologyBwp1 = list(map(float,self.numerologyBwp1))
        self.bandwidthBwp1 = self.doc['scenario']['bandwidthBwp1']
        self.bandwidthBwp1 = list(map(float,self.bandwidthBwp1))
        self.frequencyBwp1 = self.doc['scenario']['frequencyBwp1']
        #self.numerologyBwp2 = self.doc['scenario']['numerologyBwp2']
        #self.numerologyBwp2 = list(map(float,self.numerologyBwp2))
        self.bandwidthBwp2 = self.doc['scenario']['bandwidthBwp2']
        self.bandwidthBwp2 = list(map(float,self.bandwidthBwp2))
        self.frequencyBwp2 = self.doc['scenario']['frequencyBwp2']
        self.UePosY = self.doc['scenario']['UePosY']
        self.UseBlockage = self.doc['scenario']['UseBlockage']
        self.BitRate = self.doc['scenario']['BitRate']
        self.UseCa = self.doc['scenario']['UseCa']
        #self.fixedSeed = (self.doc['scenario']['fixedSeed'])
        self.ns3_path = str(self.doc['scenario']['ns3_path'])
        self.ns3_path = os.getcwd() + '/' + self.ns3_path
        self.plot_path = os.getcwd()
        self.ns3_script = str(self.doc['scenario']['ns3_script'])
        self.nJobs = int(self.doc['scenario']['jobs'])
        if self.nJobs == 1: # disable the confidence interval
            self.plotCI = False;
        self.filename = str(self.doc['scenario']['filename'])
        self.BitRate  = self.doc['scenario']['BitRate']
    
    def doLabelbandwidthBwp1(self, bandwidthBwp1):
        # Define labels for plots legends
        return "bandwidthBwp1 = "+str(int(bandwidthBwp1[0])/1e6) + "MHz"
        
    def plotCampaign(self,curCampaign, metric):
        # some general configurations from .txt file
        # you should change it according to your problem
        #outputDir = self.ns3_path+'/results_'+self.simLocation + '_' + curCampaign        
        #outputDir = self.ns3_path+'results_'+self.simLocation + '_' + curCampaign
        #outputDir = self.ns3_path+'results_'+self.simLocation + '_' + self.campaign_name + '_' + curCampaign
        outputDir = self.plot_path
        #chFile = outputDir+ "/" + "DL_" + self.filename + '.txt'
        #resBitRate,resnumerologyBwp1,resbandwidthBwp1=[],[],[]
        #resnumerologyBwp2,resbandwidthBwp2,resUseCa=[],[],[]
        m_plr, m_plrCI, m_tput, m_tputCI, m_pkt, m_pktCI = [], [], [], [], [], []
        m_tput1,m_tput2=[],[]
        m_tputCI1,m_tputCI2=[],[]
        markers_on_all = cycle(list(itertools.product([0], [1,2,3,4,5])))
        markersA = cycle(('o', 'v', 'D', '>', 'h', '^', '*', '>', 's', 'H', 'D', 'd'))
        colors = cycle(('b', 'g', 'r', 'c', 'm', 'y', 'k'))                    
        plt.figure()     
        #for iAlg in self.algoritmo:
        nOfCurlines=2 # number of Campaign Lines in 1 simulation (max value = 3)
        SimTied = 1 # whether or not the simulation parameters are tied (0 or 1)
        if nOfCurlines == 1 and SimTied == 0:
            print("to be implemented")
        elif nOfCurlines==2 and SimTied == 0:
            print("to be implemented")
        elif nOfCurlines==3 and SimTied == 0:
            print("to be implemented")
        elif nOfCurlines==1 and SimTied == 1:
            print("to be implemented")
        elif nOfCurlines==2 and SimTied == 1:
            curLine = self.doc['scenario']['campaignLines'][0]
            vtcurLine = self.doc['scenario'][curLine]
            label = eval('self.doLabel'+self.campaignLines[0]+'(vtcurLine)')
            color=next(colors)
            marker=next(markersA)
            markers_on=next(markers_on_all)
            mm_pkt,mm_tput,mm_plr=[],[],[]
            mm_tput1,mm_tput2=[],[]
            for i in range(len(self.doc['scenario'][curLine])):
                curFileName = ("DL_Results_Results"+ 
                               "_Freq1_"+"{0:.2f}".format(int(self.frequencyBwp1[0])/1e9)+
                               "_Band1_"+str(int(self.bandwidthBwp1[i]/1e6))+
                               "_Freq2_"+"{0:.2f}".format(int(self.frequencyBwp2[i])/1e9)+
                               "_Band2_"+str(int(self.bandwidthBwp2[i]/1e6))+
                               "_BitRate_"+str(int(int(self.BitRate[0])/1e6)) +
                               "_UePosY_"+self.UePosY[0]+
                               "_UseCa_"+self.UseCa[0]+
                               "_UseBlockage_"+self.UseBlockage[0]+".txt")
                print("\n")
                for iJob in range(0,self.nJobs):
                    CurSimuFile = outputDir + "/JOB" +str(iJob) + "/" + curFileName
                    print(CurSimuFile)
                    Rx_Packets = np.loadtxt(CurSimuFile, skiprows=1, usecols=(5, ), delimiter=',', unpack=False)
                    m_pkt = np.append(m_pkt, np.sum(Rx_Packets))
                    T_put = np.loadtxt(CurSimuFile, skiprows=1, usecols=(7, ), delimiter=',', unpack=False)
                    m_tput = np.append(m_tput, np.sum(T_put))
                    m_tput1 = np.append(m_tput1, T_put[0])
                    m_tput2 = np.append(m_tput2, T_put[1])
                    Packet_Loss_Ratio = np.loadtxt(CurSimuFile, skiprows=1, usecols=(10, ), delimiter=',', unpack=False)
                    m_plr = np.append(m_plr, np.sum(Packet_Loss_Ratio))
                #Calculate CI
                l, hplr = st.t.interval(0.95, len(m_plr), loc=np.mean(m_plr), scale=st.sem(m_plr))
                l, htput = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
                l, htput1 = st.t.interval(0.95, len(m_tput1), loc=np.mean(m_tput1), scale=st.sem(m_tput1))
                l, htput2 = st.t.interval(0.95, len(m_tput2), loc=np.mean(m_tput2), scale=st.sem(m_tput2))
                l, hpkt = st.t.interval(0.95, len(m_pkt), loc=np.mean(m_pkt), scale=st.sem(m_pkt))
                m_plrCI = np.append(m_plrCI, hplr)  
                m_tputCI = np.append(m_tputCI, htput)
                m_tputCI1 = np.append(m_tputCI1, htput1)
                m_tputCI2 = np.append(m_tputCI2, htput2)
                m_pktCI = np.append(m_pktCI, hpkt)
                mm_pkt = np.append(mm_pkt, np.mean(m_pkt))
                mm_tput = np.append(mm_tput, np.mean(m_tput))
                mm_tput1 = np.append(mm_tput1, np.mean(m_tput1))
                mm_tput2 = np.append(mm_tput2, np.mean(m_tput2))
                mm_plr = np.append(mm_plr, np.mean(m_plr))
                m_pkt,m_tput,m_plr=[],[],[]
                m_tput1,m_tput2=[],[]
            
            resxDataold = eval('sorted(self.'+curCampaign+',key=int)')
            Np_resxDataold = np.array(resxDataold)
            Np_resxDataold = np.flip(Np_resxDataold)
            #resxData = [int(iterator)/np.array(self.bandwidthBwp1) for iterator in Np_resxDataold]
            resxData = np.floor(Np_resxDataold/np.array(self.bandwidthBwp1)*100)/100
            
            # Current values of y-axis metrics
            #curMetricAxis = eval('res'+curCampaign)
            #resalgIndexs = (curMetricLine == int(curLine)) & (curMetricAxis == int(varParam))                
            if str(curCampaign) == 'numerologyBwp1':
                xlabel='Numerologia BWP1 '
            elif str(curCampaign) == 'bandwidthBwp1':
                xlabel='Banda (MHz) BWP1'
            elif str(curCampaign) == 'numerologyBwp2':
                xlabel='Numerologia BWP2'
            elif str(curCampaign) == 'bandwidthBwp2':
                xlabel=' Rcc = BandBwp2 / BandBwp1'
            elif str(curCampaign) == 'UseCa':
                xlabel='UseCa'
            elif str(curCampaign) == 'BitRate':
                xlabel='Bitrate'
            label = "Total"
            label1 = "Primary CC"
            label2 = "Secondary CC"
            
            if metric=='PLR': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_plr, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                else:
                    plt.plot(resxData,mm_plr, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)  
                
                ylabel="PLR [%]"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55])
                #plt.legend(loc='best', numpoints=1) 
                #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                #plt.tight_layout()
            elif metric=='Tput': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_tput, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput1, label=label1, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput1, yerr = (m_tputCI1-mm_tput1), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput2, label=label2, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput2, yerr = (m_tputCI2-mm_tput2), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                else:
                    plt.plot(resxData,mm_tput, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput1, label=label1, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput2, label=label2, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)    
                
                ylabel="Tput [Mbps]"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55]) 
                #plt.legend(loc='best', numpoints=1)
                plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                plt.tight_layout()
            elif metric=='Pkt': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_pkt, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_pkt, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                else:
                    plt.plot(resxData,mm_pkt, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                ylabel="Pacotes recebidos"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55])
                #plt.legend(loc='upper left', numpoints=1)        
                #plt.legend(loc='best', numpoints=1)        
                #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                #plt.tight_layout()

 
        # Plot figure
        params = {'legend.fontsize': 'x-large',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
        plt.rcParams.update(params)        
        os.makedirs(outputDir+"/ps", exist_ok=True)
        os.makedirs(outputDir+"/png", exist_ok=True)
        
        if metric=='PLR':        
            if bool(self.plotCI):
                imgfilename = 'PLR_CI_'+curCampaign
            else:
                imgfilename = 'PLR_'+curCampaign
            plt.savefig(outputDir+"/png/"+imgfilename+".png")
            plt.savefig(outputDir+"/ps/"+imgfilename+".eps")
            if bool(self.showPlot):
                plt.show()
            else:
                plt.close()
                
        elif metric=='Tput':
            if bool(self.plotCI):
                imgfilename = 'TPUT_CI_'+curCampaign
            else:
                imgfilename = 'TPUT_'+curCampaign    
            plt.savefig(outputDir+"/png/"+imgfilename+".png")
            plt.savefig(outputDir+"/ps/"+imgfilename+".eps")       
            if bool(self.showPlot):
                plt.show()
            else:
                plt.close()

        elif metric=='Pkt':
            if bool(self.plotCI):
                imgfilename = 'PKT_CI_'+curCampaign
            else:
                imgfilename = 'PKT_'+curCampaign    
            plt.savefig(outputDir+"/png/"+imgfilename+".png")
            plt.savefig(outputDir+"/ps/"+imgfilename+".eps")       
            if bool(self.showPlot):
                plt.show()
            else:
                plt.close()
        elif nOfCurlines==3 and SimTied == 1:
            print("to be implemented")
          



parser = argparse.ArgumentParser()
#parser = "CaNR_campaign.yaml"
parser.add_argument("-f", "--file", type=str, help='Configuration File')
parser.add_argument("-p", "--path", type=str, help='Path')
args = parser.parse_args()
configurations_file = args.file;
plotpath = args.path;
os.chdir(plotpath)
 

with open(configurations_file, 'r') as f:
    doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
    campaign_name = os.path.splitext(configurations_file)[0]
    print('Simulação escolhida: ')

campaign = doc['scenario']['campaignX']
print(campaign)
simu = openSimulation(configurations_file)
for iMet in ['Tput']:
    for simC in campaign:
        if (str(simC) == 'numerologyBwp1' or str(simC) == 'bandwidthBwp1' 
            or str(simC) == 'numerologyBwp2' or str(simC) == 'bandwidthBwp2' 
            or str(simC) == 'BitRate'or str(simC) == 'UseCa'):
            simu.plotCampaign(simC,iMet);
        else:
            print('Invalid simulation campaign: verify the campaign parameter!')
# Out:
# Overwriting PlotNrCaScript_BenchmarkingRcc.py

# %% [markdown]
# ## For campaigns 1 and 2

# %%
# %cd "/home/daniel/ns-3/NR/ns-3-dev-nr/ScriptsPlot"
# Out:
# /home/daniel/ns-3/NR/ns-3-dev-nr/ScriptsPlot

# %%
# %%file PlotNrCaScript_Bitrate.py
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pylab as plt
from itertools import cycle
import scipy.stats as st
import os
import argparse
import yaml
import matplotlib
from random import randint   
import itertools  


class openSimulation:
    def __init__(self, configurations_file):
        self.email_to = 'fulano@gmail.com'            
        with open(configurations_file, 'r') as f:
            self.doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
            #self.doc = doc
        self.campaign_name = os.path.splitext(configurations_file)[0]
        
        # Read commom parameters
        self.showPlot = True;
        self.plotCI = True;                
        self.campaignX = self.doc['scenario']['campaignX']
        self.campaignLines = self.doc['scenario']['campaignLines']
        self.simLocation = str(doc['scenario']['simLocation'])
        self.SimTime = self.doc['scenario']['SimTime']
        #self.numerologyBwp1 = self.doc['scenario']['numerologyBwp1']
        #self.numerologyBwp1 = list(map(float,self.numerologyBwp1))
        self.bandwidthBwp1 = self.doc['scenario']['bandwidthBwp1']
        self.bandwidthBwp1 = list(map(float,self.bandwidthBwp1))
        self.frequencyBwp1 = self.doc['scenario']['frequencyBwp1']
        #self.numerologyBwp2 = self.doc['scenario']['numerologyBwp2']
        #self.numerologyBwp2 = list(map(float,self.numerologyBwp2))
        self.bandwidthBwp2 = self.doc['scenario']['bandwidthBwp2']
        self.bandwidthBwp2 = list(map(float,self.bandwidthBwp2))
        self.frequencyBwp2 = self.doc['scenario']['frequencyBwp2']
        self.UePosY = self.doc['scenario']['UePosY']
        self.UseBlockage = self.doc['scenario']['UseBlockage']
        self.BitRate = self.doc['scenario']['BitRate']
        self.UseCa = self.doc['scenario']['UseCa']
        #self.fixedSeed = (self.doc['scenario']['fixedSeed'])
        self.ns3_path = str(self.doc['scenario']['ns3_path'])
        self.ns3_path = os.getcwd() + '/' + self.ns3_path
        self.plot_path = os.getcwd()
        self.ns3_script = str(self.doc['scenario']['ns3_script'])
        self.nJobs = int(self.doc['scenario']['jobs'])
        if self.nJobs == 1: # disable the confidence interval
            self.plotCI = False;
        self.filename = str(self.doc['scenario']['filename'])
        self.BitRate  = self.doc['scenario']['BitRate']
        self.nOfCurlines=self.doc['scenario']['nOfCurlines']
        self.SimTied = self.doc['scenario']['SimTied']
        self.nOfCurlinesTied = self.doc['scenario']['nOfCurlinesTied']
    
    def doLabelbandwidthBwp1(self, bandwidthBwp1):
        # Define labels for plots legends
        return "bandwidthBwp1 = "+str(int(bandwidthBwp1[0])/1e6) + "MHz"
        
    def plotCampaign(self,curCampaign, metric):
        # some general configurations from .txt file
        # you should change it according to your problem
        #outputDir = self.ns3_path+'/results_'+self.simLocation + '_' + curCampaign        
        #outputDir = self.ns3_path+'results_'+self.simLocation + '_' + curCampaign
        #outputDir = self.ns3_path+'results_'+self.simLocation + '_' + self.campaign_name + '_' + curCampaign
        outputDir = self.plot_path
        #chFile = outputDir+ "/" + "DL_" + self.filename + '.txt'
        #resBitRate,resnumerologyBwp1,resbandwidthBwp1=[],[],[]
        #resnumerologyBwp2,resbandwidthBwp2,resUseCa=[],[],[]
        m_plr, m_plrCI, m_tput, m_tputCI, m_pkt, m_pktCI = [], [], [], [], [], []
        m_tput1,m_tput2=[],[]
        m_tputCI1,m_tputCI2,m_tputCI3,m_tputCI4=[],[],[],[]
        markers_on_all = cycle(list(itertools.product([0], [1,2,3,4,5])))
        markersA = cycle(('o', 'v', 'D', '>', 'h', '^', '*', '>', 's', 'H', 'D', 'd'))
        colors = cycle(('b', 'g', 'r', 'c', 'm', 'y', 'k'))                    
        plt.figure()     
        #for iAlg in self.algoritmo:
        nOfCurlines=int(self.nOfCurlines[0]) # number of Campaign Lines in 1 simulation (max value = 3)
        SimTied = int(self.SimTied[0]) # whether or not the simulation parameters are tied (0 or 1)
        nOfCurlinesTied = int(self.nOfCurlinesTied[0]) # number of Campaign Lines tied (max value = nOfCurlines)
        print (nOfCurlines, SimTied,nOfCurlinesTied)
        if nOfCurlines == 1 and SimTied == 0:
            print("to be implemented")
        elif nOfCurlines==2 and SimTied == 0:
            print("to be implemented")
        elif nOfCurlines==3 and SimTied == 0:
            print("to be implemented")
        elif nOfCurlines==1 and SimTied == 1:
            print("to be implemented")
        elif nOfCurlines==2 and SimTied == 1 and nOfCurlinesTied == 2:
            curLine = self.doc['scenario']['campaignLines'][0]
            curLinePlus = self.doc['scenario']['campaignLines'][nOfCurlines-nOfCurlinesTied+1]
            campaignX = self.campaignX[0]
            vtcurLine = self.doc['scenario'][curLine]
            #curLine = self.doc['scenario']['campaignLines'][0]
            vtcurLine = self.doc['scenario'][curLine]
            #label = eval('self.doLabel'+self.campaignLines[0]+'(vtcurLine)')
            color=next(colors)
            marker=next(markersA)
            markers_on=next(markers_on_all)
            mm_pkt,mm_tput,mm_plr=[],[],[]
            mm_tput1,mm_tput2,mm_tput3,mm_tput4=[],[],[],[]
            #self.campaignX
            for iCampaignX in range(len(self.doc['scenario'][campaignX])):
                for i in range(len(self.doc['scenario'][curLine])):
                    #for j in range(len(self.doc['scenario'][curLinePlus])):
                    curFileName = ("DL_Results_Results"+ 
                                   "_Freq1_"+"{0:.2f}".format(int(self.frequencyBwp1[0])/1e9)+
                                   "_Band1_"+str(int(self.bandwidthBwp1[i]/1e6))+
                                   "_Freq2_"+"{0:.2f}".format(int(self.frequencyBwp2[0])/1e9)+
                                   "_Band2_"+str(int(self.bandwidthBwp2[0]/1e6))+
                                   "_BitRate_"+str(int(int(self.BitRate[iCampaignX])/1e6)) +
                                   "_UePosY_"+self.UePosY[0]+
                                   "_UseCa_"+self.UseCa[i]+
                                   "_UseBlockage_"+self.UseBlockage[0]+".txt")
                    #print(curFileName)
                    for iJob in range(0,self.nJobs):
                        CurSimuFile = outputDir + "/JOB" +str(iJob) + "/" + curFileName
                        #print(CurSimuFile)
                        Rx_Packets = np.loadtxt(CurSimuFile, skiprows=1, usecols=(5, ), delimiter=',', unpack=False)
                        m_pkt = np.append(m_pkt, np.sum(Rx_Packets))
                        T_put = np.loadtxt(CurSimuFile, skiprows=1, usecols=(7, ), delimiter=',', unpack=False)
                        m_tput = np.append(m_tput, np.sum(T_put))
                        if self.UseCa[i] == 1:
                            m_tput1 = np.append(m_tput1, T_put[0])
                            m_tput2 = np.append(m_tput2, T_put[1])
                        Packet_Loss_Ratio = np.loadtxt(CurSimuFile, skiprows=1, usecols=(10, ), delimiter=',', unpack=False)
                        m_plr = np.append(m_plr, np.sum(Packet_Loss_Ratio))
                    #Calculate CI
                    l, hplr = st.t.interval(0.95, len(m_plr), loc=np.mean(m_plr), scale=st.sem(m_plr))
                    l, htput = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
     
                    if self.UseCa[i] == '0' and self.UseBlockage[0] == '0':  
                        mm_tput1 = np.append(mm_tput1, np.mean(m_tput))
                        l, htput1 = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))                           
                        m_tputCI1 = np.append(m_tputCI1, htput1)
                    elif self.UseCa[i] == '0' and self.UseBlockage[0] == '1':
                        mm_tput2 = np.append(mm_tput2, np.mean(m_tput))
                        l, htput2 = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
                        m_tputCI2 = np.append(m_tputCI2, htput2)
                    elif self.UseCa[i] == '1' and self.UseBlockage[0] == '0':
                        mm_tput3 = np.append(mm_tput3, np.mean(m_tput))
                        l, htput3 = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
                        m_tputCI3 = np.append(m_tputCI3, htput3)
                    elif self.UseCa[i] == '1' and self.UseBlockage[0] == '1':
                        mm_tput4 = np.append(mm_tput4, np.mean(m_tput))
                        l, htput4 = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
                        m_tputCI4 = np.append(m_tputCI4, htput4)
                    #m_pktCI = np.append(m_pktCI, hpkt)
                    #mm_pkt = np.append(mm_pkt, np.mean(m_pkt))
                    #mm_tput = np.append(mm_tput, np.mean(m_tput))
                    #mm_plr = np.append(mm_plr, np.mean(m_plr))
                    m_pkt,m_tput,m_plr=[],[],[]
        
            resxDataold = eval('sorted(self.'+curCampaign+',key=int)')
            Np_resxDataold = np.array(resxDataold)
            #Np_resxDataold = np.flip(Np_resxDataold)
            resxData = [int(iterator)/1000000000 for iterator in Np_resxDataold]
            #resxData = np.floor(Np_resxDataold/np.array(self.bandwidthBwp1)*100)/100
            # Current values of y-axis metrics
            #curMetricAxis = eval('res'+curCampaign)
            #resalgIndexs = (curMetricLine == int(curLine)) & (curMetricAxis == int(varParam))                
            if str(curCampaign) == 'numerologyBwp1':
                xlabel='Numerologia BWP1 '
            elif str(curCampaign) == 'bandwidthBwp1':
                xlabel='Banda (MHz) BWP1'
            elif str(curCampaign) == 'numerologyBwp2':
                xlabel='Numerologia BWP2'
            elif str(curCampaign) == 'bandwidthBwp2':
                xlabel=' Rcc = BandBwp2 / BandBwp1'
            elif str(curCampaign) == 'UseCa':
                xlabel='UseCa'
            elif str(curCampaign) == 'BitRate':
                xlabel='Taxa de Transmissão (Gbps)'
            label = "Sem CA"
            label1 = "UseCa = 0 and UseBlockage=1"
            label2 = "Com CA"
            label3 = "UseCa = 1 and UseBlockage=1"
            
            if metric=='PLR': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_plr, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                else:
                    plt.plot(resxData,mm_plr, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)  
                
                ylabel="PLR [%]"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55])
                #plt.legend(loc='best', numpoints=1) 
                #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                #plt.tight_layout()
            elif metric=='Tput': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                #plt.figure(figsize=(10,5))
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_tput1, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput1, yerr = (m_tputCI1-mm_tput1), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    """plt.plot(resxData,mm_tput2, label=label1, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput2, yerr = (m_tputCI2-mm_tput2), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)"""
                    
                    plt.plot(resxData,mm_tput3, label=label2, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput3, yerr = (m_tputCI3-mm_tput3), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    """plt.plot(resxData,mm_tput4, label=label3, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput4, yerr = (m_tputCI4-mm_tput4), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)"""
                    
                else:
                    plt.plot(resxData,mm_tput1, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput2, label=label1, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput3, label=label2, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput4, label=label3, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)    
                
                ylabel="Taxa Útil [Mbps]"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                #plt.xlim([0.10, 0.55]) 
                #plt.legend(loc='best', numpoints=1)
                plt.legend(loc='center left', bbox_to_anchor=(0.2, 0.13))
                plt.grid()
                #plt.tight_layout()
                plt.show()
            elif metric=='Pkt': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_pkt, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_pkt, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                else:
                    plt.plot(resxData,mm_pkt, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                ylabel="Pacotes recebidos"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55])
                #plt.legend(loc='upper left', numpoints=1)        
                #plt.legend(loc='best', numpoints=1)        
                #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                #plt.tight_layout()
                    
            
            # Plot figure
            params = {'legend.fontsize': 'x-large',
             'axes.labelsize': 'x-large',
             'axes.titlesize':'x-large',
             'xtick.labelsize':'x-large',
             'ytick.labelsize':'x-large'}
            plt.rcParams.update(params)        
            os.makedirs(outputDir+"/ps", exist_ok=True)
            os.makedirs(outputDir+"/png", exist_ok=True)
            
            if metric=='PLR':        
                if bool(self.plotCI):
                    imgfilename = 'PLR_CI_'+curCampaign
                else:
                    imgfilename = 'PLR_'+curCampaign
                plt.savefig(outputDir+"/png/"+imgfilename+".png")
                plt.savefig(outputDir+"/ps/"+imgfilename+".eps")
                if bool(self.showPlot):
                    plt.show()
                else:
                    plt.close()
                    
            elif metric=='Tput':
                if bool(self.plotCI):
                    imgfilename = 'TPUT_CI_'+curCampaign
                else:
                    imgfilename = 'TPUT_'+curCampaign    
                plt.savefig(outputDir+"/png/"+imgfilename+".png")
                plt.savefig(outputDir+"/ps/"+imgfilename+".eps")       
                if bool(self.showPlot):
                    plt.show()
                else:
                    plt.close()
    
            elif metric=='Pkt':
                if bool(self.plotCI):
                    imgfilename = 'PKT_CI_'+curCampaign
                else:
                    imgfilename = 'PKT_'+curCampaign    
                plt.savefig(outputDir+"/png/"+imgfilename+".png")
                plt.savefig(outputDir+"/ps/"+imgfilename+".eps")       
                if bool(self.showPlot):
                    plt.show()
                else:
                    plt.close()
            elif nOfCurlines==3 and SimTied == 1:
                print("to be implemented")
        elif nOfCurlines==3 and SimTied == 1 and nOfCurlinesTied == 2:
            curLine = self.doc['scenario']['campaignLines'][0]
            curLinePlusPlus = self.doc['scenario']['campaignLines'][nOfCurlines-nOfCurlinesTied+1]
            campaignX = self.campaignX[0]
            vtcurLine = self.doc['scenario'][curLine]
            #label = eval('self.doLabel'+self.campaignLines[0]+'(vtcurLine)')
            color=next(colors)
            marker=next(markersA)
            markers_on=next(markers_on_all)
            mm_pkt,mm_tput,mm_plr=[],[],[]
            mm_tput1,mm_tput2,mm_tput3,mm_tput4=[],[],[],[]
            #self.campaignX
            for iCampaignX in range(len(self.doc['scenario'][campaignX])):
                for i in range(len(self.doc['scenario'][curLine])):
                    for j in range(len(self.doc['scenario'][curLinePlusPlus])):
                        curFileName = ("DL_Results_Results"+ 
                                       "_Freq1_"+"{0:.2f}".format(int(self.frequencyBwp1[0])/1e9)+
                                       "_Band1_"+str(int(self.bandwidthBwp1[i]/1e6))+
                                       "_Freq2_"+"{0:.2f}".format(int(self.frequencyBwp2[0])/1e9)+
                                       "_Band2_"+str(int(self.bandwidthBwp2[0]/1e6))+
                                       "_BitRate_"+str(int(int(self.BitRate[iCampaignX])/1e6)) +
                                       "_UePosY_"+self.UePosY[0]+
                                       "_UseCa_"+self.UseCa[i]+
                                       "_UseBlockage_"+self.UseBlockage[j]+".txt")
                        #print(curFileName)
                        for iJob in range(0,self.nJobs):
                            CurSimuFile = outputDir + "/JOB" +str(iJob) + "/" + curFileName
                            #print(CurSimuFile)
                            Rx_Packets = np.loadtxt(CurSimuFile, skiprows=1, usecols=(5, ), delimiter=',', unpack=False)
                            m_pkt = np.append(m_pkt, np.sum(Rx_Packets))
                            T_put = np.loadtxt(CurSimuFile, skiprows=1, usecols=(7, ), delimiter=',', unpack=False)
                            m_tput = np.append(m_tput, np.sum(T_put))
                            if self.UseCa[i] == 1:
                                m_tput1 = np.append(m_tput1, T_put[0])
                                m_tput2 = np.append(m_tput2, T_put[1])
                            Packet_Loss_Ratio = np.loadtxt(CurSimuFile, skiprows=1, usecols=(10, ), delimiter=',', unpack=False)
                            m_plr = np.append(m_plr, np.sum(Packet_Loss_Ratio))
                        #Calculate CI
                        l, hplr = st.t.interval(0.95, len(m_plr), loc=np.mean(m_plr), scale=st.sem(m_plr))
                        l, htput = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
         
                        if self.UseCa[i] == '0' and self.UseBlockage[j] == '0':  
                            mm_tput1 = np.append(mm_tput1, np.mean(m_tput))
                            l, htput1 = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))                           
                            m_tputCI1 = np.append(m_tputCI1, htput1)
                        elif self.UseCa[i] == '0' and self.UseBlockage[j] == '1':
                            mm_tput2 = np.append(mm_tput2, np.mean(m_tput))
                            l, htput2 = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
                            m_tputCI2 = np.append(m_tputCI2, htput2)
                        elif self.UseCa[i] == '1' and self.UseBlockage[j] == '0':
                            mm_tput3 = np.append(mm_tput3, np.mean(m_tput))
                            l, htput3 = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
                            m_tputCI3 = np.append(m_tputCI3, htput3)
                        elif self.UseCa[i] == '1' and self.UseBlockage[j] == '1':
                            mm_tput4 = np.append(mm_tput4, np.mean(m_tput))
                            l, htput4 = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
                            m_tputCI4 = np.append(m_tputCI4, htput4)
                        #m_pktCI = np.append(m_pktCI, hpkt)
                        #mm_pkt = np.append(mm_pkt, np.mean(m_pkt))
                        #mm_tput = np.append(mm_tput, np.mean(m_tput))
                        #mm_plr = np.append(mm_plr, np.mean(m_plr))
                        m_pkt,m_tput,m_plr=[],[],[]
        
            resxDataold = eval('sorted(self.'+curCampaign+',key=int)')
            Np_resxDataold = np.array(resxDataold)
            #Np_resxDataold = np.flip(Np_resxDataold)
            resxData = [int(iterator)/1000000000 for iterator in Np_resxDataold]
            #resxData = np.floor(Np_resxDataold/np.array(self.bandwidthBwp1)*100)/100
            # Current values of y-axis metrics
            #curMetricAxis = eval('res'+curCampaign)
            #resalgIndexs = (curMetricLine == int(curLine)) & (curMetricAxis == int(varParam))                
            if str(curCampaign) == 'numerologyBwp1':
                xlabel='Numerologia BWP1 '
            elif str(curCampaign) == 'bandwidthBwp1':
                xlabel='Banda (MHz) BWP1'
            elif str(curCampaign) == 'numerologyBwp2':
                xlabel='Numerologia BWP2'
            elif str(curCampaign) == 'bandwidthBwp2':
                xlabel=' Rcc = BandBwp2 / BandBwp1'
            elif str(curCampaign) == 'UseCa':
                xlabel='UseCa'
            elif str(curCampaign) == 'BitRate':
                xlabel='Taxa de Transmissão (Gbps)'
            label = "Sem CA"
            label1 = "UseCa = 0 and UseBlockage=1"
            label2 = "Com CA"
            label3 = "UseCa = 1 and UseBlockage=1"
            
            if metric=='PLR': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_plr, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                else:
                    plt.plot(resxData,mm_plr, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)  
                
                ylabel="PLR [%]"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55])
                #plt.legend(loc='best', numpoints=1) 
                #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                #plt.tight_layout()
            elif metric=='Tput': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                #plt.figure(figsize=(10,5))
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_tput1, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput1, yerr = (m_tputCI1-mm_tput1), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    """plt.plot(resxData,mm_tput2, label=label1, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput2, yerr = (m_tputCI2-mm_tput2), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)"""
                    
                    plt.plot(resxData,mm_tput3, label=label2, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput3, yerr = (m_tputCI3-mm_tput3), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    """plt.plot(resxData,mm_tput4, label=label3, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput4, yerr = (m_tputCI4-mm_tput4), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)"""
                    
                else:
                    plt.plot(resxData,mm_tput1, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput2, label=label1, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput3, label=label2, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput4, label=label3, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)    
                
                ylabel="Taxa Útil [Mbps]"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                #plt.xlim([0.10, 0.55]) 
                #plt.legend(loc='best', numpoints=1)
                plt.legend(loc='center left', bbox_to_anchor=(0.2, 0.13))
                plt.grid()
                #plt.tight_layout()
                plt.show()
            elif metric=='Pkt': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_pkt, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_pkt, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                else:
                    plt.plot(resxData,mm_pkt, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                ylabel="Pacotes recebidos"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55])
                #plt.legend(loc='upper left', numpoints=1)        
                #plt.legend(loc='best', numpoints=1)        
                #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                #plt.tight_layout()
                    
            
            # Plot figure
            params = {'legend.fontsize': 'x-large',
             'axes.labelsize': 'x-large',
             'axes.titlesize':'x-large',
             'xtick.labelsize':'x-large',
             'ytick.labelsize':'x-large'}
            plt.rcParams.update(params)        
            os.makedirs(outputDir+"/ps", exist_ok=True)
            os.makedirs(outputDir+"/png", exist_ok=True)
            
            if metric=='PLR':        
                if bool(self.plotCI):
                    imgfilename = 'PLR_CI_'+curCampaign
                else:
                    imgfilename = 'PLR_'+curCampaign
                plt.savefig(outputDir+"/png/"+imgfilename+".png")
                plt.savefig(outputDir+"/ps/"+imgfilename+".eps")
                if bool(self.showPlot):
                    plt.show()
                else:
                    plt.close()
                    
            elif metric=='Tput':
                if bool(self.plotCI):
                    imgfilename = 'TPUT_CI_'+curCampaign
                else:
                    imgfilename = 'TPUT_'+curCampaign    
                plt.savefig(outputDir+"/png/"+imgfilename+".png")
                plt.savefig(outputDir+"/ps/"+imgfilename+".eps")       
                if bool(self.showPlot):
                    plt.show()
                else:
                    plt.close()
    
            elif metric=='Pkt':
                if bool(self.plotCI):
                    imgfilename = 'PKT_CI_'+curCampaign
                else:
                    imgfilename = 'PKT_'+curCampaign    
                plt.savefig(outputDir+"/png/"+imgfilename+".png")
                plt.savefig(outputDir+"/ps/"+imgfilename+".eps")       
                if bool(self.showPlot):
                    plt.show()
                else:
                    plt.close()
            elif nOfCurlines==3 and SimTied == 1:
                print("to be implemented")
          

parser = argparse.ArgumentParser()
#parser = "CaNR_campaign.yaml"
parser.add_argument("-f", "--file", type=str, help='Configuration File')
parser.add_argument("-p", "--path", type=str, help='Path')
args = parser.parse_args()
configurations_file = args.file;
plotpath = args.path;
os.chdir(plotpath)
 
with open(configurations_file, 'r') as f:
    doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
    campaign_name = os.path.splitext(configurations_file)[0]
    print('Simulação escolhida: ')

"""
#For debug purposes:
plotpath = "/media/daniel/SharedDisk/Clouds/Insync/SharedWithMe/UFRN/GITHUB/ns3-nr/Campaigns/results_cluster_NrCa_Scenario3gpp_SimPerScript_campaign1_BitRate"
os.chdir(plotpath)

doc = {'scenario': {'nOfCurlines': ['2'],
  'SimTied': ['1'],
  'nOfCurlinesTied': ['2'],
  'daytime': ['1'],
  'htime': ['12'],
  'ntasks': ['12'],
  'ns3_path': '',
  'ns3_script': 'NrCa-Scenario3gpp',
  'cluster_path': '/home/drdluna/ns-3-dev-nr/',
  'filename': 'CampaignNrCa',
  'simLocation': 'cluster',
  'campaignX': ['BitRate'],
  'campaignLines': ['UseCa', 'bandwidthBwp1'],
  'jobs': '10',
  'SimTime': '5',
  'frequencyBwp1': ['24000000000'],
  'bandwidthBwp1': ['800000000', '400000000'],
  'frequencyBwp2': ['24400000000'],
  'bandwidthBwp2': ['400000000'],
  'BitRate': ['2000000000',
   '2500000000',
   '3000000000',
   '3500000000',
   '4500000000'],
  'UseCa': ['0', '1'],
  'UseBlockage': ['0'],
  'UePosY': ['1']}}

configurations_file = "NrCa_Scenario3gpp_SimPerScript_campaign1.yaml"

"""
campaign = doc['scenario']['campaignX']
print(campaign)
simu = openSimulation(configurations_file)
#print(doc)
for iMet in ['Tput']:
    for simC in campaign:
        if (str(simC) == 'numerologyBwp1' or str(simC) == 'bandwidthBwp1' 
            or str(simC) == 'numerologyBwp2' or str(simC) == 'bandwidthBwp2' 
            or str(simC) == 'BitRate'or str(simC) == 'UseCa' or str(simC) == 'UePosY'):
            simu.plotCampaign(simC,iMet);
        else:
            print('Invalid simulation campaign: verify the campaign parameter!')
# Out:
# Overwriting PlotNrCaScript_Bitrate.py

# %% [markdown]
# ## For campaigns 3 and 4

# %%
# %cd "/home/daniel/ns-3/NR/ns-3-dev-nr/ScriptsPlot"
# Out:
# /home/daniel/ns-3/NR/ns-3-dev-nr/ScriptsPlot

# %%
# %%file PlotNrCaScript_Rcc.py
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pylab as plt
from itertools import cycle
import scipy.stats as st
import os
import argparse
import yaml
import matplotlib
from random import randint   
import itertools  


class openSimulation:
    def __init__(self, configurations_file):
        self.email_to = 'fulano@gmail.com'            
        with open(configurations_file, 'r') as f:
            self.doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
            #self.doc = doc
        self.campaign_name = os.path.splitext(configurations_file)[0]
        
        # Read commom parameters
        self.showPlot = True;
        self.plotCI = True;                
        self.campaignX = self.doc['scenario']['campaignX']
        self.campaignLines = self.doc['scenario']['campaignLines']
        self.simLocation = str(doc['scenario']['simLocation'])
        self.SimTime = self.doc['scenario']['SimTime']
        #self.numerologyBwp1 = self.doc['scenario']['numerologyBwp1']
        #self.numerologyBwp1 = list(map(float,self.numerologyBwp1))
        self.bandwidthBwp1 = self.doc['scenario']['bandwidthBwp1']
        self.bandwidthBwp1 = list(map(float,self.bandwidthBwp1))
        self.frequencyBwp1 = self.doc['scenario']['frequencyBwp1']
        #self.numerologyBwp2 = self.doc['scenario']['numerologyBwp2']
        #self.numerologyBwp2 = list(map(float,self.numerologyBwp2))
        self.bandwidthBwp2 = self.doc['scenario']['bandwidthBwp2']
        self.bandwidthBwp2 = list(map(float,self.bandwidthBwp2))
        self.frequencyBwp2 = self.doc['scenario']['frequencyBwp2']
        self.UePosY = self.doc['scenario']['UePosY']
        self.UseBlockage = self.doc['scenario']['UseBlockage']
        self.BitRate = self.doc['scenario']['BitRate']
        self.UseCa = self.doc['scenario']['UseCa']
        #self.fixedSeed = (self.doc['scenario']['fixedSeed'])
        self.ns3_path = str(self.doc['scenario']['ns3_path'])
        self.ns3_path = os.getcwd() + '/' + self.ns3_path
        self.plot_path = os.getcwd()
        self.ns3_script = str(self.doc['scenario']['ns3_script'])
        self.nJobs = int(self.doc['scenario']['jobs'])
        if self.nJobs == 1: # disable the confidence interval
            self.plotCI = False;
        self.filename = str(self.doc['scenario']['filename'])
        self.BitRate  = self.doc['scenario']['BitRate']
        self.nOfCurlines=self.doc['scenario']['nOfCurlines']
        self.SimTied = self.doc['scenario']['SimTied']
        self.nOfCurlinesTied = self.doc['scenario']['nOfCurlinesTied']
    
    def doLabelbandwidthBwp1(self, bandwidthBwp1):
        # Define labels for plots legends
        return "bandwidthBwp1 = "+str(int(bandwidthBwp1[0])/1e6) + "MHz"
        
    def plotCampaign(self,curCampaign, metric):
        # some general configurations from .txt file
        # you should change it according to your problem
        #outputDir = self.ns3_path+'/results_'+self.simLocation + '_' + curCampaign        
        #outputDir = self.ns3_path+'results_'+self.simLocation + '_' + curCampaign
        #outputDir = self.ns3_path+'results_'+self.simLocation + '_' + self.campaign_name + '_' + curCampaign
        outputDir = self.plot_path
        #chFile = outputDir+ "/" + "DL_" + self.filename + '.txt'
        #resBitRate,resnumerologyBwp1,resbandwidthBwp1=[],[],[]
        #resnumerologyBwp2,resbandwidthBwp2,resUseCa=[],[],[]
        m_plr, m_plrCI, m_tput, m_tputCI, m_pkt, m_pktCI = [], [], [], [], [], []
        m_tput1,m_tput2=[],[]
        m_tputCI1,m_tputCI2=[],[]
        markers_on_all = cycle(list(itertools.product([0], [1,2,3,4,5])))
        markersA = cycle(('o', 'v', 'D', '>', 'h', '^', '*', '>', 's', 'H', 'D', 'd'))
        colors = cycle(('b', 'g', 'r', 'c', 'm', 'y', 'k'))                    
        plt.figure()     
        #for iAlg in self.algoritmo:
        nOfCurlines=int(self.nOfCurlines[0]) # number of Campaign Lines in 1 simulation (max value = 3)
        SimTied = int(self.SimTied[0]) # whether or not the simulation parameters are tied (0 or 1)
        nOfCurlinesTied = int(self.nOfCurlinesTied[0]) # number of Campaign Lines tied (max value = nOfCurlines)
        print (nOfCurlines, SimTied,nOfCurlinesTied)
        if nOfCurlines == 1 and SimTied == 0:
            print("to be implemented")
        elif nOfCurlines==2 and SimTied == 0:
            print("to be implemented")
        elif nOfCurlines==3 and SimTied == 0:
            print("to be implemented")
        elif nOfCurlines==1 and SimTied == 1:
            print("to be implemented")
        elif nOfCurlines==2 and SimTied == 1 and nOfCurlinesTied == 2:
            curLine = self.doc['scenario']['campaignLines'][0]
            vtcurLine = self.doc['scenario'][curLine]
            label = eval('self.doLabel'+self.campaignLines[0]+'(vtcurLine)')
            color=next(colors)
            marker=next(markersA)
            markers_on=next(markers_on_all)
            mm_pkt,mm_tput,mm_plr=[],[],[]
            mm_tput1,mm_tput2=[],[]
            for i in range(len(self.doc['scenario'][curLine])):
                curFileName = ("DL_Results_Results"+ 
                               "_Freq1_"+"{0:.2f}".format(int(self.frequencyBwp1[0])/1e9)+
                               "_Band1_"+str(int(self.bandwidthBwp1[i]/1e6))+
                               "_Freq2_"+"{0:.2f}".format(int(self.frequencyBwp2[i])/1e9)+
                               "_Band2_"+str(int(self.bandwidthBwp2[i]/1e6))+
                               "_BitRate_"+str(int(int(self.BitRate[0])/1e6)) +
                               "_UePosY_"+self.UePosY[0]+
                               "_UseCa_"+self.UseCa[0]+
                               "_UseBlockage_"+self.UseBlockage[0]+".txt")
                print("\n")
                for iJob in range(0,self.nJobs):
                    CurSimuFile = outputDir + "/JOB" +str(iJob) + "/" + curFileName
                    print(CurSimuFile)
                    Rx_Packets = np.loadtxt(CurSimuFile, skiprows=1, usecols=(5, ), delimiter=',', unpack=False)
                    m_pkt = np.append(m_pkt, np.sum(Rx_Packets))
                    T_put = np.loadtxt(CurSimuFile, skiprows=1, usecols=(7, ), delimiter=',', unpack=False)
                    m_tput = np.append(m_tput, np.sum(T_put))
                    m_tput1 = np.append(m_tput1, T_put[0])
                    m_tput2 = np.append(m_tput2, T_put[1])
                    Packet_Loss_Ratio = np.loadtxt(CurSimuFile, skiprows=1, usecols=(10, ), delimiter=',', unpack=False)
                    m_plr = np.append(m_plr, np.sum(Packet_Loss_Ratio))
                #Calculate CI
                l, hplr = st.t.interval(0.95, len(m_plr), loc=np.mean(m_plr), scale=st.sem(m_plr))
                l, htput = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
                l, htput1 = st.t.interval(0.95, len(m_tput1), loc=np.mean(m_tput1), scale=st.sem(m_tput1))
                l, htput2 = st.t.interval(0.95, len(m_tput2), loc=np.mean(m_tput2), scale=st.sem(m_tput2))
                l, hpkt = st.t.interval(0.95, len(m_pkt), loc=np.mean(m_pkt), scale=st.sem(m_pkt))
                m_plrCI = np.append(m_plrCI, hplr)  
                m_tputCI = np.append(m_tputCI, htput)
                m_tputCI1 = np.append(m_tputCI1, htput1)
                m_tputCI2 = np.append(m_tputCI2, htput2)
                m_pktCI = np.append(m_pktCI, hpkt)
                mm_pkt = np.append(mm_pkt, np.mean(m_pkt))
                mm_tput = np.append(mm_tput, np.mean(m_tput))
                mm_tput1 = np.append(mm_tput1, np.mean(m_tput1))
                mm_tput2 = np.append(mm_tput2, np.mean(m_tput2))
                mm_plr = np.append(mm_plr, np.mean(m_plr))
                m_pkt,m_tput,m_plr=[],[],[]
                m_tput1,m_tput2=[],[]
            
            resxDataold = eval('sorted(self.'+curCampaign+',key=int)')
            Np_resxDataold = np.array(resxDataold)
            Np_resxDataold = np.flip(Np_resxDataold)
            #resxData = [int(iterator)/np.array(self.bandwidthBwp1) for iterator in Np_resxDataold]
            resxData = np.floor(Np_resxDataold/np.array(self.bandwidthBwp1)*100)/100
            
            # Current values of y-axis metrics
            #curMetricAxis = eval('res'+curCampaign)
            #resalgIndexs = (curMetricLine == int(curLine)) & (curMetricAxis == int(varParam))                
            if str(curCampaign) == 'numerologyBwp1':
                xlabel='Numerologia BWP1 '
            elif str(curCampaign) == 'bandwidthBwp1':
                xlabel='Banda (MHz) BWP1'
            elif str(curCampaign) == 'numerologyBwp2':
                xlabel='Numerologia BWP2'
            elif str(curCampaign) == 'bandwidthBwp2':
                xlabel=' Rcc = BandBwp2 / BandBwp1'
            elif str(curCampaign) == 'UseCa':
                xlabel='UseCa'
            elif str(curCampaign) == 'BitRate':
                xlabel='Bitrate'
            label = "Total"
            label1 = "Primary CC"
            label2 = "Secondary CC"
            
            if metric=='PLR': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_plr, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                else:
                    plt.plot(resxData,mm_plr, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)  
                
                ylabel="PLR [%]"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55])
                #plt.legend(loc='best', numpoints=1) 
                #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                #plt.tight_layout()
            elif metric=='Tput': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_tput, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput1, label=label1, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput1, yerr = (m_tputCI1-mm_tput1), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput2, label=label2, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput2, yerr = (m_tputCI2-mm_tput2), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                else:
                    plt.plot(resxData,mm_tput, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput1, label=label1, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput2, label=label2, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)    
                
                ylabel="Tput [Mbps]"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55]) 
                #plt.legend(loc='best', numpoints=1)
                plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                plt.tight_layout()
            elif metric=='Pkt': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_pkt, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_pkt, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                else:
                    plt.plot(resxData,mm_pkt, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                ylabel="Pacotes recebidos"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55])
                #plt.legend(loc='upper left', numpoints=1)        
                #plt.legend(loc='best', numpoints=1)        
                #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                #plt.tight_layout()

 
        # Plot figure
        params = {'legend.fontsize': 'x-large',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
        plt.rcParams.update(params)        
        os.makedirs(outputDir+"/ps", exist_ok=True)
        os.makedirs(outputDir+"/png", exist_ok=True)
        
        if metric=='PLR':        
            if bool(self.plotCI):
                imgfilename = 'PLR_CI_'+curCampaign
            else:
                imgfilename = 'PLR_'+curCampaign
            plt.savefig(outputDir+"/png/"+imgfilename+".png")
            plt.savefig(outputDir+"/ps/"+imgfilename+".eps")
            if bool(self.showPlot):
                plt.show()
            else:
                plt.close()
                
        elif metric=='Tput':
            if bool(self.plotCI):
                imgfilename = 'TPUT_CI_'+curCampaign
            else:
                imgfilename = 'TPUT_'+curCampaign    
            plt.savefig(outputDir+"/png/"+imgfilename+".png")
            plt.savefig(outputDir+"/ps/"+imgfilename+".eps")       
            if bool(self.showPlot):
                plt.show()
            else:
                plt.close()

        elif metric=='Pkt':
            if bool(self.plotCI):
                imgfilename = 'PKT_CI_'+curCampaign
            else:
                imgfilename = 'PKT_'+curCampaign    
            plt.savefig(outputDir+"/png/"+imgfilename+".png")
            plt.savefig(outputDir+"/ps/"+imgfilename+".eps")       
            if bool(self.showPlot):
                plt.show()
            else:
                plt.close()
        elif nOfCurlines==3 and SimTied == 1:
            print("to be implemented")
          



parser = argparse.ArgumentParser()
#parser = "CaNR_campaign.yaml"
parser.add_argument("-f", "--file", type=str, help='Configuration File')
parser.add_argument("-p", "--path", type=str, help='Path')
args = parser.parse_args()
configurations_file = args.file;
plotpath = args.path;
os.chdir(plotpath)
 

with open(configurations_file, 'r') as f:
    doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
    campaign_name = os.path.splitext(configurations_file)[0]
    print('Simulação escolhida: ')

campaign = doc['scenario']['campaignX']
print(campaign)
simu = openSimulation(configurations_file)
for iMet in ['Tput']:
    for simC in campaign:
        if (str(simC) == 'numerologyBwp1' or str(simC) == 'bandwidthBwp1' 
            or str(simC) == 'numerologyBwp2' or str(simC) == 'bandwidthBwp2' 
            or str(simC) == 'BitRate'or str(simC) == 'UseCa'):
            simu.plotCampaign(simC,iMet);
        else:
            print('Invalid simulation campaign: verify the campaign parameter!')
# Out:
# Overwriting PlotNrCaScript_Rcc.py

# %% [markdown]
# ## For campaign 5

# %%
# %cd "/home/daniel/ns-3/NR/ns-3-dev-nr/ScriptsPlot"
# Out:
# /home/daniel/ns-3/NR/ns-3-dev-nr/ScriptsPlot

# %%
# %%file PlotNrCaScript_UePosY.py
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pylab as plt
from itertools import cycle
import scipy.stats as st
import os
import argparse
import yaml
import matplotlib
from random import randint   
import itertools  


class openSimulation:
    def __init__(self, configurations_file):
        self.email_to = 'fulano@gmail.com'            
        with open(configurations_file, 'r') as f:
            self.doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
            #self.doc = doc
        self.campaign_name = os.path.splitext(configurations_file)[0]
        
        # Read commom parameters
        self.showPlot = True;
        self.plotCI = True;                
        self.campaignX = self.doc['scenario']['campaignX']
        self.campaignLines = self.doc['scenario']['campaignLines']
        self.simLocation = str(doc['scenario']['simLocation'])
        self.SimTime = self.doc['scenario']['SimTime']
        #self.numerologyBwp1 = self.doc['scenario']['numerologyBwp1']
        #self.numerologyBwp1 = list(map(float,self.numerologyBwp1))
        self.bandwidthBwp1 = self.doc['scenario']['bandwidthBwp1']
        self.bandwidthBwp1 = list(map(float,self.bandwidthBwp1))
        self.frequencyBwp1 = self.doc['scenario']['frequencyBwp1']
        #self.numerologyBwp2 = self.doc['scenario']['numerologyBwp2']
        #self.numerologyBwp2 = list(map(float,self.numerologyBwp2))
        self.bandwidthBwp2 = self.doc['scenario']['bandwidthBwp2']
        self.bandwidthBwp2 = list(map(float,self.bandwidthBwp2))
        self.frequencyBwp2 = self.doc['scenario']['frequencyBwp2']
        self.UePosY = self.doc['scenario']['UePosY']
        self.UseBlockage = self.doc['scenario']['UseBlockage']
        self.BitRate = self.doc['scenario']['BitRate']
        self.UseCa = self.doc['scenario']['UseCa']
        #self.fixedSeed = (self.doc['scenario']['fixedSeed'])
        self.ns3_path = str(self.doc['scenario']['ns3_path'])
        self.ns3_path = os.getcwd() + '/' + self.ns3_path
        self.plot_path = os.getcwd()
        self.ns3_script = str(self.doc['scenario']['ns3_script'])
        self.nJobs = int(self.doc['scenario']['jobs'])
        if self.nJobs == 1: # disable the confidence interval
            self.plotCI = False;
        self.filename = str(self.doc['scenario']['filename'])
        self.BitRate  = self.doc['scenario']['BitRate']
        self.nOfCurlines=self.doc['scenario']['nOfCurlines']
        self.SimTied = self.doc['scenario']['SimTied']
        self.nOfCurlinesTied = self.doc['scenario']['nOfCurlinesTied']
    
    def doLabelbandwidthBwp1(self, bandwidthBwp1):
        # Define labels for plots legends
        return "bandwidthBwp1 = "+str(int(bandwidthBwp1[0])/1e6) + "MHz"
        
    def plotCampaign(self,curCampaign, metric):
        # some general configurations from .txt file
        # you should change it according to your problem
        #outputDir = self.ns3_path+'/results_'+self.simLocation + '_' + curCampaign        
        #outputDir = self.ns3_path+'results_'+self.simLocation + '_' + curCampaign
        #outputDir = self.ns3_path+'results_'+self.simLocation + '_' + self.campaign_name + '_' + curCampaign
        outputDir = self.plot_path
        #chFile = outputDir+ "/" + "DL_" + self.filename + '.txt'
        #resBitRate,resnumerologyBwp1,resbandwidthBwp1=[],[],[]
        #resnumerologyBwp2,resbandwidthBwp2,resUseCa=[],[],[]
        m_plr, m_plrCI, m_tput, m_tputCI, m_pkt, m_pktCI = [], [], [], [], [], []
        m_tput1,m_tput2=[],[]
        m_tputCI1,m_tputCI2,m_tputCI3,m_tputCI4=[],[],[],[]
        markers_on_all = cycle(list(itertools.product([0], [1,2,3,4,5])))
        markersA = cycle(('o', 'v', 'D', '>', 'h', '^', '*', '>', 's', 'H', 'D', 'd'))
        colors = cycle(('b', 'g', 'r', 'c', 'm', 'y', 'k'))                    
        plt.figure()     
        #for iAlg in self.algoritmo:
        nOfCurlines=int(self.nOfCurlines[0]) # number of Campaign Lines in 1 simulation (max value = 3)
        SimTied = int(self.SimTied[0]) # whether or not the simulation parameters are tied (0 or 1)
        nOfCurlinesTied = int(self.nOfCurlinesTied[0]) # number of Campaign Lines tied (max value = nOfCurlines)
        print (nOfCurlines, SimTied,nOfCurlinesTied)
        if nOfCurlines == 1 and SimTied == 0:
            print("to be implemented")
        elif nOfCurlines==2 and SimTied == 0:
            print("to be implemented")
        elif nOfCurlines==3 and SimTied == 0:
            print("to be implemented")
        elif nOfCurlines==1 and SimTied == 1:
            print("to be implemented")
        elif nOfCurlines==2 and SimTied == 1 and nOfCurlinesTied == 2:
            curLine = self.doc['scenario']['campaignLines'][0]
            vtcurLine = self.doc['scenario'][curLine]
            label = eval('self.doLabel'+self.campaignLines[0]+'(vtcurLine)')
            color=next(colors)
            marker=next(markersA)
            markers_on=next(markers_on_all)
            mm_pkt,mm_tput,mm_plr=[],[],[]
            mm_tput1,mm_tput2=[],[]
            for i in range(len(self.doc['scenario'][curLine])):
                curFileName = ("DL_Results_Results"+ 
                               "_Freq1_"+"{0:.2f}".format(int(self.frequencyBwp1[0])/1e9)+
                               "_Band1_"+str(int(self.bandwidthBwp1[i]/1e6))+
                               "_Freq2_"+"{0:.2f}".format(int(self.frequencyBwp2[i])/1e9)+
                               "_Band2_"+str(int(self.bandwidthBwp2[i]/1e6))+
                               "_BitRate_"+str(int(int(self.BitRate[0])/1e6)) +
                               "_UePosY_"+self.UePosY[0]+
                               "_UseCa_"+self.UseCa[0]+
                               "_UseBlockage_"+self.UseBlockage[0]+".txt")
                print("\n")
                
                for iJob in range(0,self.nJobs):
                    CurSimuFile = outputDir + "/JOB" +str(iJob) + "/" + curFileName
                    print(CurSimuFile)
                    Rx_Packets = np.loadtxt(CurSimuFile, skiprows=1, usecols=(5, ), delimiter=',', unpack=False)
                    m_pkt = np.append(m_pkt, np.sum(Rx_Packets))
                    T_put = np.loadtxt(CurSimuFile, skiprows=1, usecols=(7, ), delimiter=',', unpack=False)
                    m_tput = np.append(m_tput, np.sum(T_put))
                    m_tput1 = np.append(m_tput1, T_put[0])
                    m_tput2 = np.append(m_tput2, T_put[1])
                    Packet_Loss_Ratio = np.loadtxt(CurSimuFile, skiprows=1, usecols=(10, ), delimiter=',', unpack=False)
                    m_plr = np.append(m_plr, np.sum(Packet_Loss_Ratio))
                #Calculate CI
                l, hplr = st.t.interval(0.95, len(m_plr), loc=np.mean(m_plr), scale=st.sem(m_plr))
                l, htput = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
                l, htput1 = st.t.interval(0.95, len(m_tput1), loc=np.mean(m_tput1), scale=st.sem(m_tput1))
                l, htput2 = st.t.interval(0.95, len(m_tput2), loc=np.mean(m_tput2), scale=st.sem(m_tput2))
                l, hpkt = st.t.interval(0.95, len(m_pkt), loc=np.mean(m_pkt), scale=st.sem(m_pkt))
                m_plrCI = np.append(m_plrCI, hplr)  
                m_tputCI = np.append(m_tputCI, htput)
                m_tputCI1 = np.append(m_tputCI1, htput1)
                m_tputCI2 = np.append(m_tputCI2, htput2)
                m_pktCI = np.append(m_pktCI, hpkt)
                mm_pkt = np.append(mm_pkt, np.mean(m_pkt))
                mm_tput = np.append(mm_tput, np.mean(m_tput))
                mm_tput1 = np.append(mm_tput1, np.mean(m_tput1))
                mm_tput2 = np.append(mm_tput2, np.mean(m_tput2))
                mm_plr = np.append(mm_plr, np.mean(m_plr))
                m_pkt,m_tput,m_plr=[],[],[]
                m_tput1,m_tput2=[],[]
                       
            resxDataold = eval('sorted(self.'+curCampaign+',key=int)')
            Np_resxDataold = np.array(resxDataold)
            Np_resxDataold = np.flip(Np_resxDataold)
            #resxData = [int(iterator)/np.array(self.bandwidthBwp1) for iterator in Np_resxDataold]
            resxData = np.floor(Np_resxDataold/np.array(self.bandwidthBwp1)*100)/100
            
            # Current values of y-axis metrics
            #curMetricAxis = eval('res'+curCampaign)
            #resalgIndexs = (curMetricLine == int(curLine)) & (curMetricAxis == int(varParam))                
            if str(curCampaign) == 'numerologyBwp1':
                xlabel='Numerologia BWP1 '
            elif str(curCampaign) == 'bandwidthBwp1':
                xlabel='Banda (MHz) BWP1'
            elif str(curCampaign) == 'numerologyBwp2':
                xlabel='Numerologia BWP2'
            elif str(curCampaign) == 'bandwidthBwp2':
                xlabel=' Rcc = BandBwp2 / BandBwp1'
            elif str(curCampaign) == 'UseCa':
                xlabel='UseCa'
            elif str(curCampaign) == 'BitRate':
                xlabel='Bitrate (Gbps)'
            label = "Total"
            label1 = "Primary CC"
            label2 = "Secondary CC"
            
            if metric=='PLR': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_plr, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                else:
                    plt.plot(resxData,mm_plr, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)  
                
                ylabel="PLR [%]"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55])
                #plt.legend(loc='best', numpoints=1) 
                #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                #plt.tight_layout()
            elif metric=='Tput': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_tput, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput1, label=label1, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput1, yerr = (m_tputCI1-mm_tput1), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput2, label=label2, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput2, yerr = (m_tputCI2-mm_tput2), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                else:
                    plt.plot(resxData,mm_tput, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput1, label=label1, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput2, label=label2, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)    
                
                ylabel="Tput [Mbps]"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55]) 
                #plt.legend(loc='best', numpoints=1)
                plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                plt.tight_layout()
            elif metric=='Pkt': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_pkt, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_pkt, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                else:
                    plt.plot(resxData,mm_pkt, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                ylabel="Pacotes recebidos"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55])
                #plt.legend(loc='upper left', numpoints=1)        
                #plt.legend(loc='best', numpoints=1)        
                #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                #plt.tight_layout()
        elif nOfCurlines==3 and SimTied == 1 and nOfCurlinesTied == 2:
            curLine = self.doc['scenario']['campaignLines'][0]
            curLinePlusPlus = self.doc['scenario']['campaignLines'][nOfCurlines-nOfCurlinesTied+1]
            campaignX = self.campaignX[0]
            vtcurLine = self.doc['scenario'][curLine]
            #label = eval('self.doLabel'+self.campaignLines[0]+'(vtcurLine)')
            color=next(colors)
            marker=next(markersA)
            markers_on=next(markers_on_all)
            mm_pkt,mm_tput,mm_plr=[],[],[]
            mm_tput1,mm_tput2,mm_tput3,mm_tput4=[],[],[],[]
            #self.campaignX
            for iCampaignX in range(len(self.doc['scenario'][campaignX])):
                for i in range(len(self.doc['scenario'][curLine])):
                    for j in range(len(self.doc['scenario'][curLinePlusPlus])):
                        curFileName = ("DL_Results_Results"+ 
                                       "_Freq1_"+"{0:.2f}".format(int(self.frequencyBwp1[0])/1e9)+
                                       "_Band1_"+str(int(self.bandwidthBwp1[i]/1e6))+
                                       "_Freq2_"+"{0:.2f}".format(int(self.frequencyBwp2[0])/1e9)+
                                       "_Band2_"+str(int(self.bandwidthBwp2[0]/1e6))+
                                       "_BitRate_"+str(int(int(self.BitRate[0])/1e6)) +
                                       "_UePosY_"+self.UePosY[iCampaignX]+
                                       "_UseCa_"+self.UseCa[i]+
                                       "_UseBlockage_"+self.UseBlockage[j]+".txt")
                        #print("\n")
                        for iJob in range(0,self.nJobs):
                            CurSimuFile = outputDir + "/JOB" +str(iJob) + "/" + curFileName
                            #print(CurSimuFile)
                            Rx_Packets = np.loadtxt(CurSimuFile, skiprows=1, usecols=(5, ), delimiter=',', unpack=False)
                            m_pkt = np.append(m_pkt, np.sum(Rx_Packets))
                            T_put = np.loadtxt(CurSimuFile, skiprows=1, usecols=(7, ), delimiter=',', unpack=False)
                            m_tput = np.append(m_tput, np.sum(T_put))
                            if self.UseCa[i] == 1:
                                m_tput1 = np.append(m_tput1, T_put[0])
                                m_tput2 = np.append(m_tput2, T_put[1])
                            Packet_Loss_Ratio = np.loadtxt(CurSimuFile, skiprows=1, usecols=(10, ), delimiter=',', unpack=False)
                            m_plr = np.append(m_plr, np.sum(Packet_Loss_Ratio))
                        #Calculate CI
                        l, hplr = st.t.interval(0.95, len(m_plr), loc=np.mean(m_plr), scale=st.sem(m_plr))
                        l, htput = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
         
                        if self.UseCa[i] == '0' and self.UseBlockage[j] == '0':  
                            mm_tput1 = np.append(mm_tput1, np.mean(m_tput))
                            l, htput1 = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))                           
                            m_tputCI1 = np.append(m_tputCI1, htput1)
                        elif self.UseCa[i] == '0' and self.UseBlockage[j] == '1':
                            mm_tput2 = np.append(mm_tput2, np.mean(m_tput))
                            l, htput2 = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
                            m_tputCI2 = np.append(m_tputCI2, htput2)
                        elif self.UseCa[i] == '1' and self.UseBlockage[j] == '0':
                            mm_tput3 = np.append(mm_tput3, np.mean(m_tput))
                            l, htput3 = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
                            m_tputCI3 = np.append(m_tputCI3, htput3)
                        elif self.UseCa[i] == '1' and self.UseBlockage[j] == '1':
                            mm_tput4 = np.append(mm_tput4, np.mean(m_tput))
                            l, htput4 = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
                            m_tputCI4 = np.append(m_tputCI4, htput4)
                        #m_pktCI = np.append(m_pktCI, hpkt)
                        #mm_pkt = np.append(mm_pkt, np.mean(m_pkt))
                        #mm_tput = np.append(mm_tput, np.mean(m_tput))
                        #mm_plr = np.append(mm_plr, np.mean(m_plr))
                        m_pkt,m_tput,m_plr=[],[],[]
        
            resxDataold = eval('sorted(self.'+curCampaign+',key=int)')
            Np_resxDataold = np.array(resxDataold)
            #Np_resxDataold = np.flip(Np_resxDataold)
            #resxData = [int(iterator)/1000000000 for iterator in Np_resxDataold]
            resxData = Np_resxDataold
            #resxData = np.floor(Np_resxDataold/np.array(self.bandwidthBwp1)*100)/100
            # Current values of y-axis metrics
            #curMetricAxis = eval('res'+curCampaign)
            #resalgIndexs = (curMetricLine == int(curLine)) & (curMetricAxis == int(varParam))                
            if str(curCampaign) == 'numerologyBwp1':
                xlabel='Numerologia BWP1 '
            elif str(curCampaign) == 'bandwidthBwp1':
                xlabel='Banda (MHz) BWP1'
            elif str(curCampaign) == 'numerologyBwp2':
                xlabel='Numerologia BWP2'
            elif str(curCampaign) == 'bandwidthBwp2':
                xlabel=' Rcc = BandBwp2 / BandBwp1'
            elif str(curCampaign) == 'UseCa':
                xlabel='UseCa'
            elif str(curCampaign) == 'BitRate':
                xlabel='Bitrate (Gbps)'
            elif str(curCampaign) == 'UePosY':
                xlabel= 'Distance from UE to gNB'
                
            label = "UseCa = 0 and UseBlockage=0"
            label1 = "UseCa = 0 and UseBlockage=1"
            label2 = "UseCa = 1 and UseBlockage=0"
            label3 = "UseCa = 1 and UseBlockage=1"
            
            if metric=='PLR': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_plr, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                else:
                    plt.plot(resxData,mm_plr, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)  
                
                ylabel="PLR [%]"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55])
                #plt.legend(loc='best', numpoints=1) 
                #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                #plt.tight_layout()
            elif metric=='Tput': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                plt.figure(figsize=(20,10))
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_tput1, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput1, yerr = (m_tputCI1-mm_tput1), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput2, label=label1, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput2, yerr = (m_tputCI2-mm_tput2), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput3, label=label2, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput3, yerr = (m_tputCI3-mm_tput3), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput4, label=label3, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput4, yerr = (m_tputCI4-mm_tput4), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                else:
                    plt.plot(resxData,mm_tput1, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput2, label=label1, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput3, label=label2, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput4, label=label3, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all) 
                
                ylabel="Tput [Mbps]"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                #plt.xlim([0.10, 0.55]) 
                #plt.legend(loc='best', numpoints=1)
                plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                plt.tight_layout()
                plt.show()
            elif metric=='Pkt': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_pkt, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_pkt, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                else:
                    plt.plot(resxData,mm_pkt, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                ylabel="Pacotes recebidos"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55])
                #plt.legend(loc='upper left', numpoints=1)        
                #plt.legend(loc='best', numpoints=1)        
                #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                #plt.tight_layout()
                    
            
            # Plot figure
            params = {'legend.fontsize': 'x-large',
             'axes.labelsize': 'x-large',
             'axes.titlesize':'x-large',
             'xtick.labelsize':'x-large',
             'ytick.labelsize':'x-large'}
            plt.rcParams.update(params)        
            os.makedirs(outputDir+"/ps", exist_ok=True)
            os.makedirs(outputDir+"/png", exist_ok=True)
            
            if metric=='PLR':        
                if bool(self.plotCI):
                    imgfilename = 'PLR_CI_'+curCampaign
                else:
                    imgfilename = 'PLR_'+curCampaign
                plt.savefig(outputDir+"/png/"+imgfilename+".png")
                plt.savefig(outputDir+"/ps/"+imgfilename+".eps")
                if bool(self.showPlot):
                    plt.show()
                else:
                    plt.close()
                    
            elif metric=='Tput':
                if bool(self.plotCI):
                    imgfilename = 'TPUT_CI_'+curCampaign
                else:
                    imgfilename = 'TPUT_'+curCampaign    
                plt.savefig(outputDir+"/png/"+imgfilename+".png")
                plt.savefig(outputDir+"/ps/"+imgfilename+".eps")       
                if bool(self.showPlot):
                    plt.show()
                else:
                    plt.close()
    
            elif metric=='Pkt':
                if bool(self.plotCI):
                    imgfilename = 'PKT_CI_'+curCampaign
                else:
                    imgfilename = 'PKT_'+curCampaign    
                plt.savefig(outputDir+"/png/"+imgfilename+".png")
                plt.savefig(outputDir+"/ps/"+imgfilename+".eps")       
                if bool(self.showPlot):
                    plt.show()
                else:
                    plt.close()
            elif nOfCurlines==3 and SimTied == 1:
                print("to be implemented")
          

parser = argparse.ArgumentParser()
#parser = "CaNR_campaign.yaml"
parser.add_argument("-f", "--file", type=str, help='Configuration File')
parser.add_argument("-p", "--path", type=str, help='Path')
args = parser.parse_args()
configurations_file = args.file;
plotpath = args.path;
os.chdir(plotpath)
 
with open(configurations_file, 'r') as f:
    doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
    campaign_name = os.path.splitext(configurations_file)[0]
    print('Simulação escolhida: ')

campaign = doc['scenario']['campaignX']
print(campaign)
simu = openSimulation(configurations_file)
for iMet in ['Tput']:
    for simC in campaign:
        if (str(simC) == 'numerologyBwp1' or str(simC) == 'bandwidthBwp1' 
            or str(simC) == 'numerologyBwp2' or str(simC) == 'bandwidthBwp2' 
            or str(simC) == 'BitRate'or str(simC) == 'UseCa' or str(simC) == 'UePosY'):
            simu.plotCampaign(simC,iMet);
        else:
            print('Invalid simulation campaign: verify the campaign parameter!')
# Out:
# Overwriting PlotNrCaScript_UePosY.py

# %% [markdown]
# ## For campaign 1 - UAN

# %%
# %cd "/home/master/ns-3/ns-allinone-3.31/ns-3.31/ScriptsPlot"
# Out:
# /home/master/ns-3/ns-allinone-3.31/ns-3.31/ScriptsPlot

# %%
# %%file PlotUan_SimPerScript_campaign1.py
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pylab as plt
from itertools import cycle
import scipy.stats as st
import os
import argparse
import yaml
import matplotlib
from random import randint   
import itertools  


class openSimulation:
    def __init__(self, configurations_file):
        self.email_to = 'fulano@gmail.com'            
        with open(configurations_file, 'r') as f:
            self.doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
            #self.doc = doc
        self.campaign_name = os.path.splitext(configurations_file)[0]
        
        # Read commom parameters
        self.showPlot = True;
        self.plotCI = True;                
        self.campaignX = self.doc['scenario']['campaignX']
        self.campaignLines = self.doc['scenario']['campaignLines']
        self.simLocation = str(doc['scenario']['simLocation'])
        self.SimTime = self.doc['scenario']['SimTime']
        self.nSinks = self.doc['scenario']['nSinks']
        self.nNodes = self.doc['scenario']['nNodes']
        self.nAuvs = self.doc['scenario']['nAuvs']
        self.AuvModel = self.doc['scenario']['AuvModel']
        self.AuvModel = list(map(int,self.AuvModel))
        self.MaxRange = self.doc['scenario']['MaxRange']
        self.MaxRange = list(map(int,self.MaxRange))
        self.PktSize = self.doc['scenario']['PktSize']
        self.NoiseModel = self.doc['scenario']['NoiseModel']
        self.PropModel = self.doc['scenario']['PropModel']
        self.ns3_path = str(self.doc['scenario']['ns3_path'])
        self.ns3_path = os.getcwd() + '/' + self.ns3_path
        self.plot_path = os.getcwd()
        self.ns3_script = str(self.doc['scenario']['ns3_script'])
        self.nJobs = int(self.doc['scenario']['jobs'])
        if self.nJobs == 1: # disable the confidence interval
            self.plotCI = False;
        self.filename = str(self.doc['scenario']['filename'])
        self.nOfCurlines=self.doc['scenario']['nOfCurlines']
        self.SimTied = self.doc['scenario']['SimTied']
        self.nOfCurlinesTied = self.doc['scenario']['nOfCurlinesTied']
    
    def doLabelAuvModel(self, auvModel):
        # Define labels for plots legends
        return "AuvModel = "+str(int(auvModel[0]))
        
    def plotCampaign(self,curCampaign, metric):
        # some general configurations from .txt file
        # you should change it according to your problem
        #outputDir = self.ns3_path+'/results_'+self.simLocation + '_' + curCampaign        
        #outputDir = self.ns3_path+'results_'+self.simLocation + '_' + curCampaign
        #outputDir = self.ns3_path+'results_'+self.simLocation + '_' + self.campaign_name + '_' + curCampaign
        outputDir = self.plot_path
        #chFile = outputDir+ "/" + "DL_" + self.filename + '.txt'
        #resBitRate,resnumerologyBwp1,resbandwidthBwp1=[],[],[]
        #resnumerologyBwp2,resbandwidthBwp2,resUseCa=[],[],[]
        m_plr, m_plrCI, m_tput, m_tputCI, m_pkt, m_pktCI = [], [], [], [], [], []
        m_tput1,m_tput2=[],[]
        m_tputCI1,m_tputCI2,m_tputCI3,m_tputCI4=[],[],[],[]
        m_pwrConsumption=[]
        markers_on_all = cycle(list(itertools.product([0], [1,2,3,4,5])))
        markersA = cycle(('o', 'v', 'D', '>', 'h', '^', '*', '>', 's', 'H', 'D', 'd'))
        colors = cycle(('b', 'g', 'r', 'c', 'm', 'y', 'k'))                    
        plt.figure()     
        #for iAlg in self.algoritmo:
        nOfCurlines=int(self.nOfCurlines[0]) # number of Campaign Lines in 1 simulation (max value = 3)
        SimTied = int(self.SimTied[0]) # whether or not the simulation parameters are tied (0 or 1)
        nOfCurlinesTied = int(self.nOfCurlinesTied[0]) # number of Campaign Lines tied (max value = nOfCurlines)
        print (nOfCurlines, SimTied,nOfCurlinesTied)
        if nOfCurlines == 1 and SimTied == 3:
            print("to be implemented")
        elif nOfCurlines==2 and SimTied == 0:
            print("to be implemented")
        elif nOfCurlines==3 and SimTied == 0:
            print("to be implemented")
        elif nOfCurlines==1 and SimTied == 1:
            print("to be implemented")
        elif nOfCurlines==1 and SimTied == 0:
            curLine = self.doc['scenario']['campaignLines'][0]
            vtcurLine = self.doc['scenario'][curLine]
            label = eval('self.doLabel'+self.campaignLines[0]+'(vtcurLine)')
            color=next(colors)
            marker=next(markersA)
            markers_on=next(markers_on_all)
            mm_pkt,mm_tput,mm_plr=[],[],[]
            mm_tput1,mm_tput2=[],[]
            mm_pwrConsumption=[]
            for i in range(len(self.doc['scenario']['MaxRange'])):
                for j in range(len(self.doc['scenario'][curLine])):       
                    curFileName = ("UL_Results_Sim_PropModel_UanPropModelIdeal"+
                                   "_MaxRange_"+str(int(self.MaxRange[i]))+
                                   "_AuvModel_"+str(int(self.AuvModel[j]))+".txt")
                    print("\n")
                
                    for iJob in range(0,self.nJobs):
                        CurSimuFile = outputDir + "/JOB" +str(iJob) + "/" + curFileName
                        print(CurSimuFile)
                        #Rx_Packets = np.loadtxt(CurSimuFile, skiprows=1, usecols=(5, ), delimiter=',', unpack=False)
                        #m_pkt = np.append(m_pkt, np.sum(Rx_Packets))
                        T_put = np.loadtxt(CurSimuFile, skiprows=1, usecols=(7, ), delimiter=',', unpack=False)
                        m_tput = np.append(m_tput, np.sum(T_put))
                        #m_tput1 = np.append(m_tput1, T_put[0])
                        #m_tput2 = np.append(m_tput2, T_put[1])
                        Packet_Loss_Ratio = np.loadtxt(CurSimuFile, skiprows=1, usecols=(10, ), delimiter=',', unpack=False)
                        m_plr = np.append(m_plr, np.sum(Packet_Loss_Ratio))
                    #Calculate CI
                    l, hplr = st.t.interval(0.95, len(m_plr), loc=np.mean(m_plr), scale=st.sem(m_plr))
                    l, htput = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
                    #l, htput1 = st.t.interval(0.95, len(m_tput1), loc=np.mean(m_tput1), scale=st.sem(m_tput1))
                    #l, htput2 = st.t.interval(0.95, len(m_tput2), loc=np.mean(m_tput2), scale=st.sem(m_tput2))
                    #l, hpkt = st.t.interval(0.95, len(m_pkt), loc=np.mean(m_pkt), scale=st.sem(m_pkt))
                    m_plrCI = np.append(m_plrCI, hplr)  
                    m_tputCI = np.append(m_tputCI, htput)
                    #m_tputCI1 = np.append(m_tputCI1, htput1)
                    #m_tputCI2 = np.append(m_tputCI2, htput2)
                    #m_pktCI = np.append(m_pktCI, hpkt)
                    #mm_pkt = np.append(mm_pkt, np.mean(m_pkt))
                    mm_tput = np.append(mm_tput, np.mean(m_tput))
                    #mm_tput1 = np.append(mm_tput1, np.mean(m_tput1))
                    #mm_tput2 = np.append(mm_tput2, np.mean(m_tput2))
                    mm_plr = np.append(mm_plr, np.mean(m_plr))
                    m_pkt,m_tput,m_plr=[],[],[]
                    #m_tput1,m_tput2=[],[]
            
            mm_plr = [mm_plr[i*3:int((i+1)*3)] for i in range(6)]

            resxDataold = eval('sorted(self.'+curCampaign+',key=int)')
            #Np_resxDataold = np.array(resxDataold)
            #Np_resxDataold = np.flip(Np_resxDataold)
            #resxData = [int(iterator)/np.array(self.bandwidthBwp1) for iterator in Np_resxDataold]
            #resxData = np.floor(Np_resxDataold/np.array(self.bandwidthBwp1)*100)/100
            resxData = np.array(resxDataold)
            # Current values of y-axis metrics
            #curMetricAxis = eval('res'+curCampaign)
            #resalgIndexs = (curMetricLine == int(curLine)) & (curMetricAxis == int(varParam))                
            if str(curCampaign) == 'MaxRange':
                xlabel='MaxRange'
            label = "Total"
            label1 = "Primary CC"
            label2 = "Secondary CC"
            
            if metric=='PLR': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):         
                    print(resxData)
                    print(mm_plr)       
                    plt.plot(resxData,mm_plr, label=label, marker=marker,color=color,markevery=markers_on)
                    #plt.errorbar(resxData,mm_tput, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                else:
                    plt.plot(resxData,mm_plr, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)  
                
                ylabel="PLR [%]"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([10, 5000])
                #plt.legend(loc='best', numpoints=1) 
                #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                #plt.tight_layout()
            elif metric=='Tput': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_tput, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput1, label=label1, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput1, yerr = (m_tputCI1-mm_tput1), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput2, label=label2, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput2, yerr = (m_tputCI2-mm_tput2), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                else:
                    plt.plot(resxData,mm_tput, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput1, label=label1, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput2, label=label2, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)    
                
                ylabel="Taxa Útil [Mbps]"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55]) 
                #plt.legend(loc='best', numpoints=1)
                plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                plt.tight_layout()
            elif metric=='Pkt': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_pkt, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_pkt, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                else:
                    plt.plot(resxData,mm_pkt, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                ylabel="Pacotes recebidos"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55])
                #plt.legend(loc='upper left', numpoints=1)        
                #plt.legend(loc='best', numpoints=1)        
                #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                #plt.tight_layout()
        elif nOfCurlines==3 and SimTied == 1 and nOfCurlinesTied == 2:
            curLine = self.doc['scenario']['campaignLines'][0]
            curLinePlusPlus = self.doc['scenario']['campaignLines'][nOfCurlines-nOfCurlinesTied+1]
            campaignX = self.campaignX[0]
            vtcurLine = self.doc['scenario'][curLine]
            #label = eval('self.doLabel'+self.campaignLines[0]+'(vtcurLine)')
            color=next(colors)
            marker=next(markersA)
            markers_on=next(markers_on_all)
            mm_pkt,mm_tput,mm_plr=[],[],[]
            mm_tput1,mm_tput2,mm_tput3,mm_tput4=[],[],[],[]
            #self.campaignX
            for iCampaignX in range(len(self.doc['scenario'][campaignX])):
                for i in range(len(self.doc['scenario'][curLine])):
                    for j in range(len(self.doc['scenario'][curLinePlusPlus])):
                        curFileName = ("DL_Results_Results"+ 
                                       "_Freq1_"+"{0:.2f}".format(int(self.frequencyBwp1[0])/1e9)+
                                       "_Band1_"+str(int(self.bandwidthBwp1[i]/1e6))+
                                       "_Freq2_"+"{0:.2f}".format(int(self.frequencyBwp2[0])/1e9)+
                                       "_Band2_"+str(int(self.bandwidthBwp2[0]/1e6))+
                                       "_BitRate_"+str(int(int(self.BitRate[0])/1e6)) +
                                       "_UePosY_"+self.UePosY[iCampaignX]+
                                       "_UseCa_"+self.UseCa[i]+
                                       "_UseBlockage_"+self.UseBlockage[j]+".txt")
                        #print("\n")
                        for iJob in range(0,self.nJobs):
                            CurSimuFile = outputDir + "/JOB" +str(iJob) + "/" + curFileName
                            #print(CurSimuFile)
                            Rx_Packets = np.loadtxt(CurSimuFile, skiprows=1, usecols=(5, ), delimiter=',', unpack=False)
                            m_pkt = np.append(m_pkt, np.sum(Rx_Packets))
                            T_put = np.loadtxt(CurSimuFile, skiprows=1, usecols=(7, ), delimiter=',', unpack=False)
                            m_tput = np.append(m_tput, np.sum(T_put))
                            if self.UseCa[i] == 1:
                                m_tput1 = np.append(m_tput1, T_put[0])
                                m_tput2 = np.append(m_tput2, T_put[1])
                            Packet_Loss_Ratio = np.loadtxt(CurSimuFile, skiprows=1, usecols=(10, ), delimiter=',', unpack=False)
                            m_plr = np.append(m_plr, np.sum(Packet_Loss_Ratio))
                        #Calculate CI
                        l, hplr = st.t.interval(0.95, len(m_plr), loc=np.mean(m_plr), scale=st.sem(m_plr))
                        l, htput = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
         
                        if self.UseCa[i] == '0' and self.UseBlockage[j] == '0':  
                            mm_tput1 = np.append(mm_tput1, np.mean(m_tput))
                            l, htput1 = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))                           
                            m_tputCI1 = np.append(m_tputCI1, htput1)
                        elif self.UseCa[i] == '0' and self.UseBlockage[j] == '1':
                            mm_tput2 = np.append(mm_tput2, np.mean(m_tput))
                            l, htput2 = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
                            m_tputCI2 = np.append(m_tputCI2, htput2)
                        elif self.UseCa[i] == '1' and self.UseBlockage[j] == '0':
                            mm_tput3 = np.append(mm_tput3, np.mean(m_tput))
                            l, htput3 = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
                            m_tputCI3 = np.append(m_tputCI3, htput3)
                        elif self.UseCa[i] == '1' and self.UseBlockage[j] == '1':
                            mm_tput4 = np.append(mm_tput4, np.mean(m_tput))
                            l, htput4 = st.t.interval(0.95, len(m_tput), loc=np.mean(m_tput), scale=st.sem(m_tput))
                            m_tputCI4 = np.append(m_tputCI4, htput4)
                        #m_pktCI = np.append(m_pktCI, hpkt)
                        #mm_pkt = np.append(mm_pkt, np.mean(m_pkt))
                        #mm_tput = np.append(mm_tput, np.mean(m_tput))
                        #mm_plr = np.append(mm_plr, np.mean(m_plr))
                        m_pkt,m_tput,m_plr=[],[],[]
        
            resxDataold = eval('sorted(self.'+curCampaign+',key=int)')
            Np_resxDataold = np.array(resxDataold)
            #Np_resxDataold = np.flip(Np_resxDataold)
            #resxData = [int(iterator)/1000000000 for iterator in Np_resxDataold]
            resxData = Np_resxDataold
            #resxData = np.floor(Np_resxDataold/np.array(self.bandwidthBwp1)*100)/100
            # Current values of y-axis metrics
            #curMetricAxis = eval('res'+curCampaign)
            #resalgIndexs = (curMetricLine == int(curLine)) & (curMetricAxis == int(varParam))                
            if str(curCampaign) == 'numerologyBwp1':
                xlabel='Numerologia BWP1 '
            elif str(curCampaign) == 'bandwidthBwp1':
                xlabel='Banda (MHz) BWP1'
            elif str(curCampaign) == 'numerologyBwp2':
                xlabel='Numerologia BWP2'
            elif str(curCampaign) == 'bandwidthBwp2':
                xlabel=' Rcc = BandBwp2 / BandBwp1'
            elif str(curCampaign) == 'UseCa':
                xlabel='UseCa'
            elif str(curCampaign) == 'BitRate':
                xlabel='Bitrate (Gbps)'
            elif str(curCampaign) == 'UePosY':
                xlabel= 'Distância entre a UE e a gNB (m)'
                
            label = "Sem CA"
            label1 = "Sem CA e com blockage"
            label2 = "Com CA"
            label3 = "Com CA e com blockage"
            
            if metric=='PLR': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_plr, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                else:
                    plt.plot(resxData,mm_plr, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)  
                
                ylabel="PLR [%]"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55])
                #plt.legend(loc='best', numpoints=1) 
                #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                #plt.tight_layout()
            elif metric=='Tput': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                plt.figure(figsize=(20,10))
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_tput1, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput1, yerr = (m_tputCI1-mm_tput1), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput2, label=label1, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput2, yerr = (m_tputCI2-mm_tput2), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput3, label=label2, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput3, yerr = (m_tputCI3-mm_tput3), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput4, label=label3, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_tput4, yerr = (m_tputCI4-mm_tput4), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                else:
                    plt.plot(resxData,mm_tput1, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput2, label=label1, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput3, label=label2, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                    
                    plt.plot(resxData,mm_tput4, label=label3, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all) 
                
                ylabel="Taxa Útil [Mbps]"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                #plt.ylim([0, 10]) 
                #plt.legend(loc='best', numpoints=1)
                plt.legend(loc='center left', bbox_to_anchor=(0.1, 0.3))
                plt.grid()
                #plt.tight_layout()
                plt.show()
            elif metric=='Pkt': # Calculate PLR line
                # Confidence interval according to https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
                if bool(self.plotCI):                
                    plt.plot(resxData,mm_pkt, label=label, marker=marker,color=color,markevery=markers_on)
                    plt.errorbar(resxData,mm_pkt, yerr = (m_tputCI-mm_tput), marker=marker,color=color, ls = 'none', lw = 2, capthick = 2,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                else:
                    plt.plot(resxData,mm_pkt, label=label, marker=marker,color=color,markevery=markers_on)
                    color=next(colors)
                    marker=next(markersA)
                    markers_on=next(markers_on_all)
                ylabel="Pacotes recebidos"
                plt.xlabel(xlabel)
                plt.ylabel(ylabel)
                plt.xlim([0.10, 0.55])
                #plt.legend(loc='upper left', numpoints=1)        
                #plt.legend(loc='best', numpoints=1)        
                #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
                plt.grid()
                #plt.tight_layout()
                    
            
            # Plot figure
            params = {'legend.fontsize': 'x-large',
             'axes.labelsize': 'x-large',
             'axes.titlesize':'x-large',
             'xtick.labelsize':'x-large',
             'ytick.labelsize':'x-large'}
            plt.rcParams.update(params)        
            os.makedirs(outputDir+"/ps", exist_ok=True)
            os.makedirs(outputDir+"/png", exist_ok=True)
            
            if metric=='PLR':        
                if bool(self.plotCI):
                    imgfilename = 'PLR_CI_'+curCampaign
                else:
                    imgfilename = 'PLR_'+curCampaign
                plt.savefig(outputDir+"/png/"+imgfilename+".png")
                plt.savefig(outputDir+"/ps/"+imgfilename+".eps")
                if bool(self.showPlot):
                    plt.show()
                else:
                    plt.close()
                    
            elif metric=='Tput':
                if bool(self.plotCI):
                    imgfilename = 'TPUT_CI_'+curCampaign
                else:
                    imgfilename = 'TPUT_'+curCampaign    
                plt.savefig(outputDir+"/png/"+imgfilename+".png")
                plt.savefig(outputDir+"/ps/"+imgfilename+".eps")       
                if bool(self.showPlot):
                    plt.show()
                else:
                    plt.close()
    
            elif metric=='Pkt':
                if bool(self.plotCI):
                    imgfilename = 'PKT_CI_'+curCampaign
                else:
                    imgfilename = 'PKT_'+curCampaign    
                plt.savefig(outputDir+"/png/"+imgfilename+".png")
                plt.savefig(outputDir+"/ps/"+imgfilename+".eps")       
                if bool(self.showPlot):
                    plt.show()
                else:
                    plt.close()
            elif nOfCurlines==3 and SimTied == 1:
                print("to be implemented")
          

parser = argparse.ArgumentParser()
#parser = "CaNR_campaign.yaml"
parser.add_argument("-f", "--file", type=str, help='Configuration File')
parser.add_argument("-p", "--path", type=str, help='Path')
args = parser.parse_args()
configurations_file = args.file;
plotpath = args.path;
os.chdir(plotpath)
 
with open(configurations_file, 'r') as f:
    doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
    campaign_name = os.path.splitext(configurations_file)[0]
    print('Simulação escolhida: ')

campaign = doc['scenario']['campaignX']
print(campaign)
simu = openSimulation(configurations_file)
for iMet in ['PLR']:
    for simC in campaign:
        if (str(simC) == 'numerologyBwp1' or str(simC) == 'bandwidthBwp1' 
            or str(simC) == 'numerologyBwp2' or str(simC) == 'bandwidthBwp2' 
            or str(simC) == 'BitRate'or str(simC) == 'UseCa' or str(simC) == 'UePosY'
            or str(simC) == 'MaxRange'):
            simu.plotCampaign(simC,iMet);
        else:
            print('Invalid simulation campaign: verify the campaign parameter!')
# Out:
# Overwriting PlotUan_SimPerScript_campaign1.py

# %%
# %%file PlotUan_SimPerScript_campaign1.py
